# %%
import pandas as pd
import os
import time
import keras_ocr
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import string
from random import randrange
import cv2

# %%
def draw_random_subdir(dataDir):
    directory_list = os.listdir(dataDir)
    directory = directory_list[randrange(len(directory_list))]
    subdirectory_list = os.listdir(dataDir + directory + '/')
    subdirectory = subdirectory_list[randrange(len(subdirectory_list))]
    image_list = os.listdir(dataDir + directory + '/'+subdirectory+'/')
    image = image_list[randrange(len(image_list))]    
    return directory, subdirectory, image

# %%
def transform_image(img):
    alpha=1.8
    beta=-50
    new_img = cv2.addWeighted(img,alpha,img,0,beta)
    name = 'L:/DATA/ISIS/keras_ocr/test_images/testing/'+directory+'_'+subdirectory+'_'+image+'_'+str(alpha)+'_'+str(beta)+'.png'
    cv2.imwrite(name, new_img)
    
    # generate multiple images to test
    new_img = keras_ocr.tools.read(name)
    y = new_img.shape[0]
    h = int(y*0.11)
    x = new_img.shape[1]
    crop_img = img[y-h:y, 0:x]
    crop_new_img = new_img[y-h:y, 0:x]

    from PIL import Image
    # Open input image in grayscale mode and get its pixels.
    pil_img = Image.open(name).convert("LA")
    width, height = pil_img.size
    pil_img_crop = pil_img.crop((0,int(height*0.89),width,height))

    # Change the colors
    black = (0,0,0)
    white = (255,255,255)
    threshold = (100,100,100)

    pixels = pil_img_crop.getdata()

    newPixels = []

    # Compare each pixel 
    for pixel in pixels:
        if pixel < threshold:
            newPixels.append(black)
        else:
            newPixels.append(white)

    # Create and save new image.
    new_pil_img_crop = Image.new("RGB",pil_img_crop.size)
    new_pil_img_crop.putdata(newPixels)

    import numpy as np
    # generate text predictions from the images
    new_pil_img_crop = np.array(new_pil_img_crop)    
    
    return([crop_img, crop_new_img, new_pil_img_crop])

# %%
detector = keras_ocr.detection.Detector()
alphabet = string.digits
recognizer = keras_ocr.recognition.Recognizer(alphabet=alphabet)
#recognizer.model.load_weights('L:/DATA/ISIS/keras_ocr/ISIS_reading.h5')
recognizer.model.load_weights('L:/DATA/ISIS/keras_ocr/ISIS_reading_v2.h5')
#recognizer.model.load_weights('L:/DATA/ISIS/keras_ocr/ISIS_reading_contrast_PIL.h5')
#recognizer.model.load_weights('L:/DATA/ISIS/keras_ocr/ISIS_reading_contrast.h5')
recognizer.compile()
pipeline = keras_ocr.pipeline.Pipeline(detector=detector, recognizer=recognizer)
# Out:
# Looking for C:\Users\mfortier\.keras-ocr\craft_mlt_25k.h5
# Provided alphabet does not match pretrained alphabet. Using backbone weights only.
# Looking for C:\Users\mfortier\.keras-ocr\crnn_kurapan_notop.h5

# %%
dataDir = 'L:/DATA/ISIS/raw_upload_20230421/'
directory, subdirectory, image = draw_random_subdir(dataDir)
img = keras_ocr.tools.read(dataDir + directory + '/' + subdirectory + '/' + image)

# %%
# Predictions
all_img = transform_image(img)
prediction_groups = pipeline.recognize(all_img[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-803b9f5f4dbd> in <module>
#       1 # Predictions
#       2 all_img = transform_image(img)
# ----> 3 prediction_groups = pipeline.recognize(all_img[1])
#
# c:\DevSoftware\Anaconda38\lib\site-packages\keras_ocr\pipeline.py in recognize(self, images, detection_kwargs, recognition_kwargs)
#      60         if recognition_kwargs is None:
#      61             recognition_kwargs = {}
# ---> 62         box_groups = self.detector.detect(images=images, **detection_kwargs)
#      63         prediction_groups = self.recognizer.recognize_from_boxes(
#      64             images=images, box_groups=box_groups, **recognition_kwargs
#
# c:\DevSoftware\Anaconda38\lib\site-packages\keras_ocr\detection.py in detect(self, images, detection_threshold, text_threshold, link_threshold, size_threshold, **kwargs)
#     775             size_threshold: The minimum area for a word.
#     776         """
# --> 777         images = [compute_input(tools.read(image)) for image in images]
#     778         boxes = getBoxes(
#     779             self.model.predict(np.array(images), **kwargs),
#
# c:\DevSoftware\Anaconda38\lib\site-packages\keras_ocr\detection.py in <listcomp>(.0)
#     775             size_threshold: The minimum area for a word.
#     776         """
# --> 777         images = [compute_input(tools.read(image)) for image in images]
#     778         boxes = getBoxes(
#     779             self.model.predict(np.array(images), **kwargs),
#
# c:\DevSoftware\Anaconda38\lib\site-packages\keras_ocr\detection.py in compute_input(image)
#      38     variance = np.array([0.229, 0.224, 0.225])
#      39
# ---> 40     image -= mean * 255
#      41     image /= variance * 255
#      42     return image
#
# ValueError: operands could not be broadcast together with shapes (1658,6) (3,) (1658,6)

# %%
all_img[0]
# Out:
# array([[[ 56,  56,  56],
#         [ 60,  60,  60],
#         [ 44,  44,  44],
#         ...,
#         [ 63,  63,  63],
#         [ 30,  30,  30],
#         [117, 117, 117]],
#
#        [[ 55,  55,  55],
#         [ 53,  53,  53],
#         [ 43,  43,  43],
#         ...,
#         [ 56,  56,  56],
#         [ 49,  49,  49],
#         [ 79,  79,  79]],
#
#        [[ 59,  59,  59],
#         [ 51,  51,  51],
#         [ 47,  47,  47],
#         ...,
#         [ 53,  53,  53],
#         [ 55,  55,  55],
#         [ 68,  68,  68]],
#
#        ...,
#
#        [[ 57,  57,  57],
#         [ 52,  52,  52],
#         [ 49,  49,  49],
#         ...,
#         [ 46,  46,  46],
#         [ 51,  51,  51],
#         [103, 103, 103]],
#
#        [[ 73,  73,  73],
#         [ 52,  52,  52],
#         [ 38,  38,  38],
#         ...,
#         [ 42,  42,  42],
#         [ 69,  69,  69],
#         [118, 118, 118]],
#
#        [[ 66,  66,  66],
#         [ 47,  47,  47],
#         [ 49,  49,  49],
#         ...,
#         [ 48,  48,  48],
#         [ 46,  46,  46],
#         [ 97,  97,  97]]], dtype=uint8)

# %%
# plot the text predictions
fig, axs = plt.subplots(nrows=len(all_img), figsize=(15, 6))
for ax, iono, predictions in zip(axs, all_img, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=iono, 
                                    predictions=predictions, 
                                    ax=ax)

# %%
numbers = list(zip(*prediction_groups[0]))[0]
print(numbers)
# Out:
# ('0800', '011', '15', '12', '51')

# %%
numbers = list(zip(*prediction_groups[1]))[0]
print(numbers)
# Out:
# ('57', '0800', '72', '01', '13', '11')

# %%
numbers = list(zip(*prediction_groups[2]))[0]
print(numbers)
# Out:
# ('72', '0800', '57', '017', '14', '41')

# %%
plt.imshow(plt.imread(dataDir + directory + '/' + subdirectory + '/' + image))

# %%
dataDir + directory + '/' + subdirectory + '/' + image
# Out:
# 'L:/DATA/ISIS/raw_upload_20230421/R014207779/B1-35-25 ISIS B D-756/Image0507.png'
