# %% [markdown]
# # Quality Analysis (General)
#
# #### Updated: May 19, 2023

# %% [markdown]
# #

# %% [markdown]
# Quality analysis pipeline after phase 2 of Alouette processing (OCR processing phase):

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns

# %%
rootDir = 'L:/DATA/Alouette_I/BATCH_I_Run2/'
resultDir = rootDir + '05_result/'
logDir = rootDir + '06_log/'

# %% [markdown]
# #

# %% [markdown]
# #### Combine BATCH I and II:

# %% [markdown]
# #

# %% [markdown]
# #### Stage 1 - Overall Statistics:

# %%
df_inventory = pd.read_csv(logDir + 'image_inventory.csv')
n_images = df_inventory['images'].sum()

# %%
df_s1 = pd.read_csv(resultDir + 'result_stage1_raw.csv', low_memory=False)

# %%
n_proc = len(df_s1.loc[df_s1['processed_image_class'] == 'num']) + len(df_s1.loc[df_s1['processed_image_class'] == 'dot'])
n_loss = len(df_s1.loc[df_s1['processed_image_class'] == 'loss'])
n_outlier = len(df_s1.loc[df_s1['processed_image_class'] == 'outlier'])
n_unproc = n_images - n_proc - n_outlier - n_loss

# %%
print('# of images: ' + str(n_images))
print('# of images processed after stage 1 processing: ' + str(n_proc))
print('% of images processed after stage 1 processing: ' + str(round(((n_proc/n_images)*100), 2)) + ' %')
print('')
print("% total loss after stage 1 processing: " + str(round((((n_unproc + n_loss + n_outlier)/n_images)*100), 2)) + ' %')
print('% of images unprocessed after stage 1 processing: ' + str(round(((n_unproc/n_images)*100), 2)) + ' %')
print("% of images classified as 'loss' after stage 1 processing: " + str(round(((n_loss/n_images)*100), 2)) + ' %')
print("% of images classified as 'outlier' after stage 1 processing: " + str(round(((n_outlier/n_images)*100), 2)) + ' %')
# Out:
# # of images: 885527
# # of images processed after stage 1 processing: 769686
# % of images processed after stage 1 processing: 86.92 %
#
# % total loss after stage 1 processing: 13.08 %
# % of images unprocessed after stage 1 processing: 5.02 %
# % of images classified as 'loss' after stage 1 processing: 4.84 %
# % of images classified as 'outlier' after stage 1 processing: 3.23 %

# %% [markdown]
# Breakdown 'loss' type:

# %%
df_loss_bd = df_s1.loc[df_s1['processed_image_class'] == 'loss'].groupby(['func_name']).count()[['filename']]
df_loss_bd.sort_values('filename', ascending=False)
# Out:
#                                                     filename
# func_name
# ionogram_content_extraction.extract_select_para...     13025
# image_segmentation.trim_raw_metadata.trimming_m...      6582
# ionogram_content_extraction.extract_all_coordin...       662
# metadata_translation.determine_leftside_metadat...       250
# image_segmentation.extract_ionogram_from_scan.e...        17

# %% [markdown]
# Breakdown 'outlier' type:

# %%
df_outlier_bd = df_s1.loc[df_s1['processed_image_class'] == 'outlier'].groupby(['func_name']).count()[['filename']]
df_outlier_bd.sort_values('filename', ascending=False)
# Out:
#                                                     filename
# func_name
# image_segmentation.segment_images_in_subdir.seg...     27349
# image_segmentation.segment_images_in_subdir.seg...      1220

# %% [markdown]
# #

# %% [markdown]
# #### Stage 2 - Overall Statistics:

# %%
df_s2 = pd.read_csv(resultDir + 'result_stage2_raw.csv', low_memory=False)

# %%
n_num2 = len(df_s2.loc[df_s2['processed_image_class'] == 'num2'])
n_num = len(df_s2.loc[df_s2['processed_image_class'] == 'num'])
n_dot = len(df_s2.loc[df_s2['processed_image_class'] == 'dot'])
n_proc2 = n_num2 + n_num + n_dot
n_loss = len(df_s2.loc[df_s2['processed_image_class'] == 'loss'])
n_outlier = len(df_s2.loc[df_s2['processed_image_class'] == 'outlier'])

# %%
print('# of images processed after stage 2 processing: ' + str(n_proc2))
print('% of images processed after stage 2 processing: ' + str(round(((n_proc2/n_images)*100), 2)) + ' %')
print('')
print("% of images classified as 'num2' after stage 2 processing: " + str(round(((n_num2/n_images)*100), 2)) + ' %')
print("% of images classified as 'num' after stage 2 processing: " + str(round(((n_num/n_images)*100), 2)) + ' %')
print("% of images classified as 'dot' after stage 2 processing: " + str(round(((n_dot/n_images)*100), 2)) + ' %')
print('')
print("% total loss after stage 2 processing: " + str(round((((n_unproc + n_loss + n_outlier)/n_images)*100), 2)) + ' %')
print("% of images classified as 'loss' after stage 2 processing: " + str(round(((n_loss/n_images)*100), 2)) + ' %')
print("% of images classified as 'outlier' after stage 2 processing: " + str(round(((n_outlier/n_images)*100), 2)) + ' %')
# Out:
# # of images processed after stage 2 processing: 164854
# % of images processed after stage 2 processing: 18.62 %
#
# % of images classified as 'num2' after stage 2 processing: 1.29 %
# % of images classified as 'num' after stage 2 processing: 15.55 %
# % of images classified as 'dot' after stage 2 processing: 1.78 %
#
# % total loss after stage 2 processing: 9.83 %
# % of images classified as 'loss' after stage 2 processing: 4.05 %
# % of images classified as 'outlier' after stage 2 processing: 0.76 %

# %% [markdown]
# Breakdown 'loss' type:

# %%
df_s2_loss = df_s2.copy(deep=True).loc[df_s2['processed_image_class'] == 'loss']
df_s2_loss['loss_summary'] = df_s2_loss['func_name'] + ', ' + df_s2_loss['details'] 
df_loss_bd = df_s2_loss.groupby(['loss_summary']).count()[['filename']]
df_loss_bd.sort_values('filename', ascending=False)
# Out:
#                                                     filename
# loss_summary
# ionogram_content_extraction.extract_select_para...        50
# image_segmentation.segment_images_in_subdir.seg...        25

# %%
df_s2_loss = df_s2.loc[df_s2['processed_image_class'] == 'loss']
df_loss_bd = df_s2_loss.groupby(['details']).count()[['filename']]
df_loss_bd.sort_values('filename', ascending=False)
# Out:
#                                          filename
# details
# metadata could not be read by OCR           23248
# OCR read metadata contains letters           2174
# metadata was interpreted to be dot type       463
# metadata was interpreted to be num type       225

# %% [markdown]
# Breakdown 'outlier' type:

# %%
df_s2_outlier = df_s2.loc[df_s2['processed_image_class'] == 'outlier']
df_outlier_bd = df_s2_outlier.groupby(['func_name']).count()[['filename']]
df_outlier_bd.sort_values('filename', ascending=False)
# Out:
#                                                     filename
# func_name
# image_segmentation.segment_images_in_subdir.seg...      6547
# image_segmentation.segment_images_in_subdir.seg...       221

# %% [markdown]
# #

# %% [markdown]
# #### Master - Overall Statistics:

# %%
df_master = pd.read_csv(resultDir + 'result_master.csv', low_memory=False)
n_master = len(df_master.loc[(~pd.isna(df_master['Station_Code'])) & (df_master['time_quality'] == 1)])

# %%
n_tq1 = len(df_master.loc[df_master['time_quality'] == 1])
n_tq2 = len(df_master.loc[df_master['time_quality'] == 2])
n_tq3 = len(df_master.loc[df_master['time_quality'] == 3])
n_tq4 = len(df_master.loc[df_master['time_quality'] == 4])

# %%
print('# of images fully read after stage 2 processing: ' + str(n_master))
print('% of images fully read after stage 2 processing (yield): ' + str(round(((n_master/n_images)*100), 2)) + ' %')
print('')
print('% time quality level 1 yield: ' + str(round(((n_tq1/n_images)*100), 2)) + ' %')
print('% at least time quality level 2: ' + str(round((((n_tq1+n_tq2)/n_images)*100), 2)) + ' %')
print('% at least time quality level 3: ' + str(round((((n_tq1+n_tq2+n_tq3)/n_images)*100), 2)) + ' %')
print('% at least time quality level 4: ' + str(round((((n_tq1+n_tq2+n_tq3+n_tq4)/n_images)*100), 2)) + ' %')
# Out:
# # of images fully read after stage 2 processing: 124528
# % of images fully read after stage 2 processing (yield): 14.06 %
#
# % time quality level 1 yield: 14.06 %
# % at least time quality level 2: 14.2 %
# % at least time quality level 3: 14.29 %
# % at least time quality level 4: 14.74 %

# %% [markdown]
# #

# %% [markdown]
# #### Data distribution by ground station:

# %%
df2 = df_master.copy(deep=True)
df2['Station_Number_Station_Code_processed_image_class'] = df2['Station_Number'].astype(int).astype(str) + '_' + df2['Station_Code'] + '_' + df2['processed_image_class']

# %%
df_master_by_stn = df2.groupby(['Station_Number']).count()[['filename']].sort_values('filename', ascending=False)
df_master_by_stn.head(10)
# Out:
#                 filename
# Station_Number
# 1.0                26303
# 5.0                22194
# 9.0                 9871
# 3.0                 9145
# 18.0                9036
# 13.0                8555
# 7.0                 8171
# 4.0                 7507
# 8.0                 6109
# 6.0                 4187

# %%
df_master_by_stnname = df2.groupby(['Station_Name']).count()[['filename']].sort_values('filename', ascending=False)
df_master_by_stnname.head(50)
# Out:
#                                           filename
# Station_Name
# Quito, Ecuador                               23067
# Blossom Point, MD, USA                       20662
# College, Fairbanks, AK, USA                  14476
# Falkland Islands (Islas Malvinas)            11734
# St. John's, NL, Canada                       11169
# Woomera, Australia                            9058
# Fort Myers, FL, USA                           8109
# Resolute Bay, NT, Canada                      7333
# Santiago, Chile                               5969
# Ottawa, Canada                                4506
# Winkfield, England, UK                        3406
# Prince Albert, SK, Canada                     2640
# Lima, Peru                                    2342
# East Grant Forks, MN, USA                     1913
# Singapore                                      500
# Orroral Valley, Australia                      495
# University of Alaska, Fairbanks, AK, USA       401
# Tromso, Norway                                 376
# Mojave, CA, USA                                231
# Gilmore Creek, Fairbanks, AK, USA              230
# Kashima, Japan                                 228
# South Point, HI, USA                           207
# Rosman, NC, USA                                190
# Boulder, CO, USA                               178
# Kauai, HI, USA                                 164
# Byrd Station, Antarctica                       162
# Tananarive, Madagascar                         156
# Antofagasta, Chile                             140
# Darwin, Australia                              107
# Las Palmas, Canary Islands, Spain              102
# Bretigny, France                                98
# Kano, Nigeria                                   93
# Johannesburg, South Africa                      80

# %%
df_master_by_stn_code = df2.groupby(['Station_Number_Station_Code_processed_image_class']).count()[['filename']].sort_values('filename', ascending=False)
df_master_by_stn_code.head(20)
# Out:
#                                                    filename
# Station_Number_Station_Code_processed_image_class
# 1_BPT_num                                             20559
# 5_QUI_num                                             13751
# 9_SOL_num                                              9679
# 18_WOO_num                                             8666
# 7_QUI_num                                              8055
# 4_NEW_num                                              7387
# 5_COL_num                                              6986
# 13_COL_num                                             6394
# 3_FTM_num                                              5821
# 1_RES_num                                              5710
# 8_SNT_num                                              4729
# 12_NEW_num                                             3650
# 3_OTT_num                                              2803
# 2_PRI_num                                              2499
# 6_LIM_num                                              2326
# 38_SOL_num2                                            1841
# 6_FTM_num                                              1701
# 50_OTT_num2                                            1617
# 43_RES_num2                                            1477
# 15_WNK_num2                                            1387

# %% [markdown]
# - show geographic distribution by metatype type
# - show geographic distribution by year
#
# - show how each ground station used the same metadata type over time (metadata composition by ground station over time)
#
#
# - Matplotlib - basemap
# - cartopy
# - ipyleaflet (interactive)
# - plotly

# %% [markdown]
# - make availability plot for each ground station
#     - could be sparklines to show amount of data vs time, by ground station

# %%
df_master['Station_Code'].unique()
# Out:
# array(['WOO', 'COL', 'FTM', 'PRI', 'NEW', 'RES', 'WNK', 'BAT', 'SNP',
#        'GRK', 'RAL', 'OTT', 'GIL', 'ANT', 'ROS', 'SPT', 'TRO', 'SOL',
#        'ULA', 'QUI', 'MOJ', 'BPT', 'JOB', 'KJP', 'BLR', 'BFR', 'SNT',
#        'HAW', 'KNO', 'DAR', 'PCI', 'MAD', 'LIM'], dtype=object)

# %%
df_master_stn = df_master.loc[df_master['Station_Code'] == 'COL']
len(df_master_stn)
# Out:
# 14476

# %%
df_master_stn.head()
# Out:
#       Directory Subdirectory       filename processed_image_class      fmin  \
# 1   R014207978F          329  Image0162.png                   dot  1.500000
# 4    R014207939        859-A         13.png                   num  1.520161
# 63  R014207979F          290  Image0305.png                   dot  1.517857
# 64  R014207979F          297  Image0145.png                   dot  1.536290
# 65  R014207979F          290  Image0288.png                   dot  1.517857
#
#       max_depth            Timestamp  time_quality  Station_Number  \
# 1    886.046512  1962-10-16 00:22:00           1.0             5.0
# 4   1296.363636  1962-10-19 00:55:58           1.0             5.0
# 63  1044.186047  1963-01-01 00:00:00           4.0             5.0
# 64  1126.190476  1963-01-01 00:00:00           4.0             5.0
# 65   346.511628  1963-01-01 00:00:00           4.0             5.0
#
#    Station_Code                 Station_Name    Lat     Lng
# 1           COL  College, Fairbanks, AK, USA  64.9N  147.8W
# 4           COL  College, Fairbanks, AK, USA  64.9N  147.8W
# 63          COL  College, Fairbanks, AK, USA  64.9N  147.8W
# 64          COL  College, Fairbanks, AK, USA  64.9N  147.8W
# 65          COL  College, Fairbanks, AK, USA  64.9N  147.8W

# %% [markdown]
# #

# %% [markdown]
# #### Construct process_summary:

# %% [markdown]
# Load data:

# %%
print(len(df_inventory))
df_inventory.head()
# Out:
# 2638
#     Directory Subdirectory  images            subdir_id
# 0  R014207815     3488-15A     273  R014207815_3488-15A
# 1  R014207815     3489-15A     281  R014207815_3489-15A
# 2  R014207815     3490-15A     198  R014207815_3490-15A
# 3  R014207815      3491-8A     289   R014207815_3491-8A
# 4  R014207815      3492-8A     334   R014207815_3492-8A

# %%
df_process_log = pd.read_csv(logDir + 'process_log.csv')
print(len(df_process_log))
df_p1 = df_process_log.sort_values('Process_timestamp', ascending=True)
df_p1 = df_p1.drop_duplicates(subset=['subdir_id'], keep='last') 
print(len(df_p1))
df_p1.head()
# Out:
# 2728
# 2639
#      Directory Subdirectory  Images_processed  Images_dot  Images_num  \
# 0   R014207821     3343-38A             320.0         0.0       314.0
# 1   R014207942      1985-1A             296.0         0.0       272.0
# 2  R014207978F          349             437.0       425.0         1.0
# 3   R014207948      1689-9B             347.0         0.0       313.0
# 4   R014207823     3598-50A             220.0         0.0       150.0
#
#    Images_loss  Images_outlier  Process_time           Process_timestamp  \
# 0          0.0             6.0    195.038564  2023-06-02 21:09:03.663018
# 1          9.0            15.0    356.434266  2023-06-02 21:15:21.548098
# 2         10.0             1.0    705.768378  2023-06-02 21:16:49.776073
# 3          5.0            29.0    433.711368  2023-06-02 21:18:01.641518
# 4         65.0             5.0    424.822451  2023-06-02 21:18:24.384342
#
#          User            subdir_id
# 0  Rav_Super2  R014207821_3343-38A
# 1  Rav_Super2   R014207942_1985-1A
# 2  Rav_Super1      R014207978F_349
# 3  Rav_Super5   R014207948_1689-9B
# 4  Rav_Super6  R014207823_3598-50A

# %%
df_process_log2 = pd.read_csv(logDir + 'process_log_OCR.csv')
print(len(df_process_log2))
df_p2 = df_process_log2.sort_values('Process_timestamp', ascending=True)
df_p2 = df_p2.drop_duplicates(subset=['subdir_id'], keep='last') 
print(len(df_p2))
df_p2.head()
# Out:
# 623
# 623
#      Directory Subdirectory  Process_time           Process_timestamp  \
# 0   R014207844     2889-43B   1005.765122  2023-06-07 12:12:39.062165
# 1   R014207821     3325-15A   1291.077647  2023-06-07 12:34:10.973654
# 2   R014207967      1445-5A    204.089671  2023-06-07 12:49:38.052339
# 3   R014207964     1593-12A    181.256849  2023-06-07 12:52:39.363190
# 4  R014207979F          280   1256.904071  2023-06-07 12:55:08.147266
#
#            User            subdir_id
# 0  Rav_SuperHP4  R014207844_2889-43B
# 1  Rav_SuperHP4  R014207821_3325-15A
# 2  Rav_SuperHP2   R014207967_1445-5A
# 3  Rav_SuperHP2  R014207964_1593-12A
# 4  Rav_SuperHP4      R014207979F_280

# %%
df_pp = pd.read_csv(resultDir + 'result_postprocess_raw.csv', low_memory=False)

# %% [markdown]
# Construct process_summary:

# %%
df_sum1 = df_inventory.merge(df_p1[['Images_processed', 'Images_loss', 'Images_outlier', 'Process_time', 'subdir_id']], how='left', on='subdir_id')
df_sum1 = df_sum1.rename(columns={
    'images': 'n_images',
    'Images_loss': 'n_stage1_loss',
    'Images_outlier': 'n_stage1_outlier',
    'Process_time': 'process_time_stage1'
})
df_sum1['n_stage1_processed'] = df_sum1['Images_processed'] - df_sum1['n_stage1_loss'] - df_sum1['n_stage1_outlier']
df_sum1['n_stage1_unprocessed'] = df_sum1['n_images'] - df_sum1['Images_processed']
df_sum1 = df_sum1[['Directory', 'Subdirectory', 'n_images', 'n_stage1_processed', 'n_stage1_unprocessed', 'n_stage1_loss',
                  'n_stage1_outlier', 'process_time_stage1', 'subdir_id']]
print(len(df_sum1))
df_sum1.sample(10)
# Out:
# 2638
#         Directory Subdirectory  n_images  n_stage1_processed  \
# 418    R014207840      3066-8A       298               294.0
# 408    R014207840     3056-13B       331               161.0
# 2604   R014207980       1024-B       364               344.0
# 2122   R014207965     1657-13A       349               325.0
# 602   R014207907F          487       555               532.0
# 2116   R014207965     1651-18B       341               316.0
# 1925   R014207960      2538-5B       332               314.0
# 2316   R014207968      1252-5A       377               362.0
# 92     R014207816     3400-A13       314               309.0
# 1865   R014207959      2298-8B       332               307.0
#
#       n_stage1_unprocessed  n_stage1_loss  n_stage1_outlier  \
# 418                    0.0            0.0               4.0
# 408                    0.0          168.0               2.0
# 2604                   2.0            1.0              17.0
# 2122                   8.0            1.0              15.0
# 602                    9.0            8.0               6.0
# 2116                   3.0            3.0              19.0
# 1925                   4.0            3.0              11.0
# 2316                   2.0            3.0              10.0
# 92                     0.0            2.0               3.0
# 1865                   9.0            1.0              15.0
#
#       process_time_stage1            subdir_id
# 418            477.152557   R014207840_3066-8A
# 408            138.385592  R014207840_3056-13B
# 2604           398.630556    R014207980_1024-B
# 2122           707.325491  R014207965_1657-13A
# 602            893.956273      R014207907F_487
# 2116           365.904787  R014207965_1651-18B
# 1925           705.937587   R014207960_2538-5B
# 2316           919.988626   R014207968_1252-5A
# 92             412.925172  R014207816_3400-A13
# 1865           552.857581   R014207959_2298-8B

# %%
df_sum2 = df_sum1.merge(df_p2[['Process_time', 'subdir_id']], how='left', on='subdir_id')
df_sum2 = df_sum2.rename(columns={
    'Process_time': 'process_time_stage2'
})
df_sum2 = df_sum2[['Directory', 'Subdirectory', 'n_images', 'n_stage1_processed', 'n_stage1_unprocessed', 'n_stage1_loss',
                  'n_stage1_outlier', 'process_time_stage1', 'process_time_stage2', 'subdir_id']]
print(len(df_sum2))
df_sum2.sample(10)
# Out:
# 2638
#         Directory Subdirectory  n_images  n_stage1_processed  \
# 618   R014207907F          504       420               377.0
# 579    R014207844     2928-43B       311                 6.0
# 1958   R014207960     2571-18B       312               298.0
# 1846   R014207958      2819-7A       357               303.0
# 385    R014207840     3033-50A       305               294.0
# 585    R014207844     2934-43B       306                 0.0
# 350    R014207832     3658-38A       267               259.0
# 1028  R014207940F          373       424               419.0
# 131    R014207821     3319-15A       302               220.0
# 684   R014207908F          571       428               420.0
#
#       n_stage1_unprocessed  n_stage1_loss  n_stage1_outlier  \
# 618                    7.0            9.0              27.0
# 579                    1.0          303.0               1.0
# 1958                   3.0            2.0               9.0
# 1846                  18.0           11.0              25.0
# 385                    0.0            2.0               9.0
# 585                    0.0          303.0               3.0
# 350                    0.0            5.0               3.0
# 1028                   0.0            4.0               1.0
# 131                    2.0           73.0               7.0
# 684                    6.0            0.0               2.0
#
#       process_time_stage1  process_time_stage2            subdir_id
# 618            883.366154                  NaN      R014207907F_504
# 579            861.140727                  NaN  R014207844_2928-43B
# 1958           940.257177                  NaN  R014207960_2571-18B
# 1846           368.041644                  NaN   R014207958_2819-7A
# 385            632.483344                  NaN  R014207840_3033-50A
# 585           1255.227789           174.359480  R014207844_2934-43B
# 350            487.349529                  NaN  R014207832_3658-38A
# 1028           347.773910                  NaN      R014207940F_373
# 131            443.574212           231.013553  R014207821_3319-15A
# 684            638.962672                  NaN      R014207908F_571

# %%
df_s2['subdir_id'] = df_s2['Directory'] + '_' + df_s2['Subdirectory']
df_sum3_ = pd.DataFrame()

for i in range(0, len(df_sum2)):
    subdir_id = df_sum2['subdir_id'].iloc[i]
    df_s2_ = df_s2[['processed_image_class', 'filename', 'subdir_id']].loc[df_s2['subdir_id'] == subdir_id]
    if len(df_s2_) > 0:
        n_s2_proc = len(df_s2_.loc[df_s2_['processed_image_class'] == 'num2']) + len(df_s2_.loc[df_s2_['processed_image_class'] == 'num']) + len(df_s2_.loc[df_s2_['processed_image_class'] == 'dot'])
        n_s2_loss = len(df_s2_.loc[df_s2_['processed_image_class'] == 'loss'])
        n_s2_outlier = len(df_s2_.loc[df_s2_['processed_image_class'] == 'outlier'])
        row = pd.DataFrame({
            'n_stage2_processed': n_s2_proc,
            'n_stage2_loss': n_s2_loss,
            'n_stage2_outlier': n_s2_outlier,
            'subdir_id': subdir_id
        }, index=[0])
        df_sum3_ = pd.concat([df_sum3_, row])

df_sum3 = df_sum2.merge(df_sum3_, how='left', on='subdir_id')
df_sum3 = df_sum3[['Directory', 'Subdirectory', 'n_images', 'n_stage1_processed', 'n_stage1_unprocessed', 'n_stage1_loss',
                  'n_stage1_outlier', 'process_time_stage1', 'process_time_stage2', 'n_stage2_processed', 'n_stage2_loss',
                  'n_stage2_outlier', 'subdir_id']]

# %%
print(len(df_sum3))
df_sum3.sample(10)
# Out:
# 2638
#         Directory Subdirectory  n_images  n_stage1_processed  \
# 609   R014207907F          495       417               406.0
# 1387   R014207949      2115-5B       332               312.0
# 2232   R014207967         1409       341               316.0
# 2009   R014207962      1482-1B       315               297.0
# 812   R014207929F          465       409               403.0
# 1380   R014207949      2108-5B       322               313.0
# 836   R014207930F          611       398               383.0
# 1437   R014207949      2165-3A       329               303.0
# 2219   R014207967     1396-13B       323               293.0
# 2542  R014207978F          352       424               404.0
#
#       n_stage1_unprocessed  n_stage1_loss  n_stage1_outlier  \
# 609                    2.0            4.0               5.0
# 1387                  10.0            4.0               6.0
# 2232                   2.0            6.0              17.0
# 2009                   2.0            0.0              16.0
# 812                    0.0            4.0               2.0
# 1380                   4.0            1.0               4.0
# 836                    2.0            8.0               5.0
# 1437                   1.0            2.0              23.0
# 2219                   3.0            1.0              26.0
# 2542                   8.0            7.0               5.0
#
#       process_time_stage1  process_time_stage2  n_stage2_processed  \
# 609            777.089789                  NaN                 NaN
# 1387          1116.402734                  NaN                 NaN
# 2232           431.086336                  NaN                 NaN
# 2009           570.877802                  NaN                 NaN
# 812            606.577156           202.636249               340.0
# 1380           782.316187                  NaN                 NaN
# 836            783.019974                  NaN                 NaN
# 1437           808.696339                  NaN                 NaN
# 2219           529.406609                  NaN                 NaN
# 2542           535.139935                  NaN                 NaN
#
#       n_stage2_loss  n_stage2_outlier            subdir_id
# 609             NaN               NaN      R014207907F_495
# 1387            NaN               NaN   R014207949_2115-5B
# 2232            NaN               NaN      R014207967_1409
# 2009            NaN               NaN   R014207962_1482-1B
# 812            67.0               2.0      R014207929F_465
# 1380            NaN               NaN   R014207949_2108-5B
# 836             NaN               NaN      R014207930F_611
# 1437            NaN               NaN   R014207949_2165-3A
# 2219            NaN               NaN  R014207967_1396-13B
# 2542            NaN               NaN      R014207978F_352

# %%
df_pp['subdir_id'] = df_pp['Directory'] + '_' + df_pp['Subdirectory']
df_sum4_ = pd.DataFrame()

for i in range(0, len(df_sum3)):
    subdir_id = df_sum3['subdir_id'].iloc[i]
    df_pp_ = df_pp[['processed_image_class', 'filename', 'subdir_id']].loc[df_pp['subdir_id'] == subdir_id]
    if len(df_pp_) > 0:
        n_pp_proc = len(df_pp_.loc[df_pp_['processed_image_class'] == 'num2']) + len(df_pp_.loc[df_pp_['processed_image_class'] == 'num']) + len(df_pp_.loc[df_pp_['processed_image_class'] == 'dot'])
        n_pp_loss = len(df_pp_.loc[df_pp_['processed_image_class'] == 'loss'])
        n_pp_outlier = len(df_pp_.loc[df_pp_['processed_image_class'] == 'outlier'])
        row = pd.DataFrame({
            'n_postprocess_processed': n_pp_proc,
            'n_postprocess_loss': n_pp_loss,
            'n_postprocess_outlier': n_pp_outlier,
            'subdir_id': subdir_id
        }, index=[0])
        df_sum4_ = pd.concat([df_sum4_, row])

df_sum4 = df_sum3.merge(df_sum4_, how='left', on='subdir_id')
df_sum4 = df_sum4[['Directory', 'Subdirectory', 'n_images', 'n_stage1_processed', 'n_stage1_unprocessed', 'n_stage1_loss',
                  'n_stage1_outlier', 'process_time_stage1', 'process_time_stage2', 'n_stage2_processed', 'n_stage2_loss',
                  'n_stage2_outlier', 'n_postprocess_processed', 'n_postprocess_loss', 'n_postprocess_outlier', 'subdir_id']]

# %%
print(len(df_sum4))
df_sum4.sample(10)
# Out:
# 2638
#         Directory Subdirectory  n_images  n_stage1_processed  \
# 2598   R014207980       1018-B       218               213.0
# 440    R014207841     3088-13B       312                49.0
# 1056  R014207940F          402       384               379.0
# 2393   R014207974        743-B       348               327.0
# 1033  R014207940F          378       415               407.0
# 2085   R014207964      1620-4A       347               330.0
# 1382   R014207949      2110-5B       321               308.0
# 323    R014207832     3631-19A       324               312.0
# 198    R014207823     3566-43A       297               290.0
# 1723   R014207956      2392-7A       324               307.0
#
#       n_stage1_unprocessed  n_stage1_loss  n_stage1_outlier  \
# 2598                   1.0            1.0               3.0
# 440                    0.0          257.0               6.0
# 1056                   2.0            3.0               0.0
# 2393                   6.0            0.0              15.0
# 1033                   4.0            2.0               2.0
# 2085                   1.0            6.0              10.0
# 1382                   1.0            4.0               8.0
# 323                    0.0            2.0              10.0
# 198                    0.0            1.0               6.0
# 1723                   3.0            4.0              10.0
#
#       process_time_stage1  process_time_stage2  n_stage2_processed  \
# 2598           414.051055                  NaN                 NaN
# 440            161.721279                  NaN                 NaN
# 1056           416.490217                  NaN                 NaN
# 2393           606.492791                  NaN                 NaN
# 1033           368.975628                  NaN                 NaN
# 2085           290.547378                  NaN                 NaN
# 1382           948.832880                  NaN                 NaN
# 323            954.004765                  NaN                 NaN
# 198           1288.524206                  NaN                 NaN
# 1723           481.885171                  NaN                 NaN
#
#       n_stage2_loss  n_stage2_outlier  n_postprocess_processed  \
# 2598            NaN               NaN                      NaN
# 440             NaN               NaN                      NaN
# 1056            NaN               NaN                      NaN
# 2393            NaN               NaN                      NaN
# 1033            NaN               NaN                      NaN
# 2085            NaN               NaN                      NaN
# 1382            NaN               NaN                      NaN
# 323             NaN               NaN                      NaN
# 198             NaN               NaN                      NaN
# 1723            NaN               NaN                      NaN
#
#       n_postprocess_loss  n_postprocess_outlier            subdir_id
# 2598                 NaN                    NaN    R014207980_1018-B
# 440                  NaN                    NaN  R014207841_3088-13B
# 1056                 NaN                    NaN      R014207940F_402
# 2393                 NaN                    NaN     R014207974_743-B
# 1033                 NaN                    NaN      R014207940F_378
# 2085                 NaN                    NaN   R014207964_1620-4A
# 1382                 NaN                    NaN   R014207949_2110-5B
# 323                  NaN                    NaN  R014207832_3631-19A
# 198                  NaN                    NaN  R014207823_3566-43A
# 1723                 NaN                    NaN   R014207956_2392-7A

# %%
df_master['subdir_id'] = df_master['Directory'] + '_' + df_master['Subdirectory']
df_sum5_ = pd.DataFrame()

for i in range(0, len(df_sum4)):
    subdir_id = df_sum4['subdir_id'].iloc[i]
    df_master_ = df_master[['processed_image_class', 'filename', 'subdir_id']].loc[df_master['subdir_id'] == subdir_id]
    if len(df_master_) > 0:
        n_mas = len(df_master_)
        n_mas_num2 = len(df_master_.loc[df_master_['processed_image_class'] == 'num2'])
        n_mas_num = len(df_master_.loc[df_master_['processed_image_class'] == 'num'])
        n_mas_dot = len(df_master_.loc[df_master_['processed_image_class'] == 'dot'])
        row = pd.DataFrame({
            'n_master': n_mas,
            'n_master_num2': n_mas_num2,
            'n_master_num': n_mas_num,
            'n_master_dot': n_mas_dot,
            'subdir_id': subdir_id
        }, index=[0])
        df_sum5_ = pd.concat([df_sum5_, row])

df_sum5 = df_sum4.merge(df_sum5_, how='left', on='subdir_id')
df_sum5 = df_sum5[['Directory', 'Subdirectory', 'n_images', 'n_stage1_processed', 'n_stage1_unprocessed', 'n_stage1_loss',
                  'n_stage1_outlier', 'process_time_stage1', 'process_time_stage2', 'n_stage2_processed', 'n_stage2_loss',
                  'n_stage2_outlier', 'n_postprocess_processed', 'n_postprocess_loss', 'n_postprocess_outlier', 
                  'n_master', 'n_master_num2', 'n_master_num', 'n_master_dot', 'subdir_id']]

# %%
print(len(df_sum5))
df_sum5.sample(10)
# Out:
# 2638
#         Directory Subdirectory  n_images  n_stage1_processed  \
# 1791   R014207957     2643-15B       343               318.0
# 2152   R014207966      1120-1B       410               389.0
# 1823   R014207958      2796-6A       717               648.0
# 2632   R014207980        993-A       375               347.0
# 2385   R014207970      1381-1B       341               324.0
# 994    R014207939        877-A       346               324.0
# 747   R014207909F          713       340               335.0
# 2509  R014207978F          319       385               350.0
# 1464   R014207951     2431-12A       367               355.0
# 2591   R014207980       1011-A       371               359.0
#
#       n_stage1_unprocessed  n_stage1_loss  n_stage1_outlier  \
# 1791                   2.0           11.0              12.0
# 2152                   2.0            3.0              16.0
# 1823                  21.0           26.0              22.0
# 2632                   3.0            9.0              16.0
# 2385                   2.0            3.0              12.0
# 994                    3.0            8.0              11.0
# 747                    2.0            2.0               1.0
# 2509                  12.0           16.0               7.0
# 1464                   1.0            5.0               6.0
# 2591                   1.0            3.0               8.0
#
#       process_time_stage1  process_time_stage2  n_stage2_processed  \
# 1791           612.447005                  NaN                 NaN
# 2152          1220.239088                  NaN                 NaN
# 1823           690.094374                  NaN                 NaN
# 2632           368.158232           215.609635               347.0
# 2385           879.400762                  NaN                 NaN
# 994            582.237674                  NaN                 NaN
# 747            367.295263           192.045273               209.0
# 2509           441.409142                  NaN                 NaN
# 1464           861.200519                  NaN                 NaN
# 2591           315.358792                  NaN                 NaN
#
#       n_stage2_loss  n_stage2_outlier  n_postprocess_processed  \
# 1791            NaN               NaN                      NaN
# 2152            NaN               NaN                      NaN
# 1823            NaN               NaN                      NaN
# 2632            9.0              16.0                    347.0
# 2385            NaN               NaN                      NaN
# 994             NaN               NaN                      NaN
# 747           128.0               1.0                    209.0
# 2509            NaN               NaN                      NaN
# 1464            NaN               NaN                      NaN
# 2591            NaN               NaN                      NaN
#
#       n_postprocess_loss  n_postprocess_outlier  n_master  n_master_num2  \
# 1791                 NaN                    NaN       NaN            NaN
# 2152                 NaN                    NaN       NaN            NaN
# 1823                 NaN                    NaN       NaN            NaN
# 2632                 9.0                   16.0     288.0            0.0
# 2385                 NaN                    NaN       NaN            NaN
# 994                  NaN                    NaN       NaN            NaN
# 747                128.0                    1.0     190.0            0.0
# 2509                 NaN                    NaN       NaN            NaN
# 1464                 NaN                    NaN       NaN            NaN
# 2591                 NaN                    NaN       NaN            NaN
#
#       n_master_num  n_master_dot            subdir_id
# 1791           NaN           NaN  R014207957_2643-15B
# 2152           NaN           NaN   R014207966_1120-1B
# 1823           NaN           NaN   R014207958_2796-6A
# 2632         288.0           0.0     R014207980_993-A
# 2385           NaN           NaN   R014207970_1381-1B
# 994            NaN           NaN     R014207939_877-A
# 747          190.0           0.0      R014207909F_713
# 2509           NaN           NaN      R014207978F_319
# 1464           NaN           NaN  R014207951_2431-12A
# 2591           NaN           NaN    R014207980_1011-A

# %%
df_sum5.to_csv(logDir + 'process_summary.csv', index=False)

# %% [markdown]
# #

# %% [markdown]
# #### Plot histograms to characterize quality of processed subdirectories:

# %%
df_summary = pd.read_csv(logDir + 'process_summary.csv')
df_summary.head()
# Out:
#     Directory Subdirectory  n_images  n_stage1_processed  \
# 0  R014207815     3488-15A       273               256.0
# 1  R014207815     3489-15A       281               266.0
# 2  R014207815     3490-15A       198               192.0
# 3  R014207815      3491-8A       289               283.0
# 4  R014207815      3492-8A       334               321.0
#
#    n_stage1_unprocessed  n_stage1_loss  n_stage1_outlier  process_time_stage1  \
# 0                   0.0            4.0              13.0          1258.799828
# 1                   0.0           10.0               5.0          1087.995773
# 2                   1.0            2.0               3.0           608.420317
# 3                   0.0            0.0               6.0           505.898933
# 4                   1.0            3.0               9.0           670.250495
#
#    process_time_stage2  n_stage2_processed  n_stage2_loss  n_stage2_outlier  \
# 0                  NaN                 NaN            NaN               NaN
# 1                  NaN                 NaN            NaN               NaN
# 2                  NaN                 NaN            NaN               NaN
# 3                  NaN                 NaN            NaN               NaN
# 4                  NaN                 NaN            NaN               NaN
#
#    n_postprocess_processed  n_postprocess_loss  n_postprocess_outlier  \
# 0                      NaN                 NaN                    NaN
# 1                      NaN                 NaN                    NaN
# 2                      NaN                 NaN                    NaN
# 3                      NaN                 NaN                    NaN
# 4                      NaN                 NaN                    NaN
#
#    n_master  n_master_num2  n_master_num  n_master_dot            subdir_id
# 0       NaN            NaN           NaN           NaN  R014207815_3488-15A
# 1       NaN            NaN           NaN           NaN  R014207815_3489-15A
# 2       NaN            NaN           NaN           NaN  R014207815_3490-15A
# 3       NaN            NaN           NaN           NaN   R014207815_3491-8A
# 4       NaN            NaN           NaN           NaN   R014207815_3492-8A

# %%
df_summary['pc_stage1_processed'] = df_summary['n_stage1_processed']/df_summary['n_images']
sns.histplot(data=df_summary, x='pc_stage1_processed', stat='percent')
# Out:
# <Axes: xlabel='pc_stage1_processed', ylabel='Percent'>

# %%
df_summary['pc_stage2_processed'] = df_summary['n_stage2_processed']/df_summary['n_images']
sns.histplot(data=df_summary, x='pc_stage2_processed', stat='percent')
# Out:
# <Axes: xlabel='pc_stage2_processed', ylabel='Percent'>

# %%
df_summary['pc_postprocess_processed'] = df_summary['n_postprocess_processed']/df_summary['n_images']
sns.histplot(data=df_summary, x='pc_postprocess_processed', stat='percent')
# Out:
# <Axes: xlabel='pc_postprocess_processed', ylabel='Percent'>

# %%
df_summary['yield'] = df_summary['n_master']/df_summary['n_images']
sns.histplot(data=df_summary, x='yield', stat='percent')
# Out:
# <Axes: xlabel='yield', ylabel='Percent'>
