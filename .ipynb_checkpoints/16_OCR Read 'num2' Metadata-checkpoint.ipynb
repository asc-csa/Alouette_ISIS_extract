# %% [markdown]
# # OCR Read 'num2' Metadata
#
# #### Updated: Apr 4, 2023

# %% [markdown]
# #

# %% [markdown]
# Test post-processing a subdirectory, to first detect if the image is of 'num2' metadata type, and then to read and record "that metadata.

# %%
import pandas as pd
import numpy as np
import os
import time
import keras_ocr

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\rnaidoo\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\rnaidoo\.keras-ocr\crnn_kurapan.h5

# %%
rootDir = 'L:/DATA/Alouette_I/BATCH_II_Run1/'
testDir = rootDir + '04_processed/R014207817/4163-03A/'
resultDir = rootDir + '05_result/'

# %% [markdown]
# #

# %% [markdown]
# #### Functions:

# %%
def read_num2_metadata(prediction_groups, subdir_path):
    
    df_results = pd.DataFrame()
    for i in range(0, len(prediction_groups)):
        df_ocr = pd.DataFrame()
        predicted_image = prediction_groups[i]
        if len(predicted_image) > 0:
            for text, box in predicted_image:
                row = pd.DataFrame({
                    'number': text,
                    'x': box[1][0],
                    'y': box[1][1]
                }, index=[0])
                df_ocr = pd.concat([df_ocr, row])
            df_ocr = df_ocr.sort_values('x').reset_index(drop=True)
        if len(df_ocr) == 6:
            if df_ocr['number'].iloc[0] == '10':
                row2 = pd.DataFrame({
                    'station_number': df_ocr['number'].iloc[1],
                    'year': df_ocr['number'].iloc[2],
                    'day_of_year': df_ocr['number'].iloc[3],
                    'hour': df_ocr['number'].iloc[4][0:2],
                    'minute': df_ocr['number'].iloc[4][2:],
                    'second': df_ocr['number'].iloc[5],
                    'filename': img_fns[batch_i + i].replace(subdir_path, '')
                }, index=[i])
                df_results = pd.concat([df_results, row2])
    
    return df_results

# %% [markdown]
# #

# %% [markdown]
# #### Process subdirectory:

# %%
batch_size = 9 # > 9 seems to lead to a 'dead kernel'

# %%
img_fns = []
for file in os.listdir(testDir):
    img_fns.append(testDir + file)

# %%
len(img_fns)
# Out:
# 304

# %%
n_batches = int(np.floor(len(img_fns)/batch_size))
n_batches
# Out:
# 33

# %%
batch_remainder = len(img_fns)%batch_size
batch_remainder
# Out:
# 7

# %%
start = time.time()

df_results = pd.DataFrame()
for i in range(0, n_batches):
    print('Starting batch... ' + str(i))
    batch_i = i*batch_size
    batch_f = batch_i + batch_size
    #imgs_ocr = [
    #    keras_ocr.tools.read(img) for img in img_fns[batch_i:batch_f]
    #]
    prediction_groups = pipeline.recognize(img_fns[batch_i:batch_f])
    df_results_ = read_num2_metadata(prediction_groups=prediction_groups, subdir_path=testDir)
    df_results = pd.concat([df_results, df_results_])
    
#Remainder
print('Finishing up...')
batch_i = n_batches*batch_size
batch_f = batch_i + batch_remainder
prediction_groups = pipeline.recognize(img_fns[batch_i:batch_f])
df_results_ = read_num2_metadata(prediction_groups=prediction_groups, subdir_path=testDir)
df_results = pd.concat([df_results, df_results_])
df_results = df_results.sort_values('filename').reset_index(drop=True)

end = time.time()
t = end - start
print('Time to OCR read all images in subdirectory: ' + str(round(t/60, 1)) + ' min')
# Out:
# Starting batch... 0
# 1/1 [==============================] - 29s 29s/step
# 2/2 [==============================] - 2s 283ms/step
# Starting batch... 1
# 1/1 [==============================] - 19s 19s/step
# 2/2 [==============================] - 1s 349ms/step
# Starting batch... 2
# 1/1 [==============================] - 17s 17s/step
# 2/2 [==============================] - 1s 323ms/step
# Starting batch... 3
# 1/1 [==============================] - 17s 17s/step
# 2/2 [==============================] - 1s 318ms/step
# Starting batch... 4
# 1/1 [==============================] - 17s 17s/step
# 3/3 [==============================] - 1s 420ms/step
# Starting batch... 5
# 1/1 [==============================] - 17s 17s/step
# 2/2 [==============================] - 1s 347ms/step
# Starting batch... 6
# 1/1 [==============================] - 17s 17s/step
# 2/2 [==============================] - 1s 378ms/step
# Starting batch... 7
# 1/1 [==============================] - 18s 18s/step
# 2/2 [==============================] - 1s 333ms/step
# Starting batch... 8
# 1/1 [==============================] - 23s 23s/step
# 2/2 [==============================] - 1s 418ms/step
# Starting batch... 9
# 1/1 [==============================] - 17s 17s/step
# 2/2 [==============================] - 1s 379ms/step
# Starting batch... 10
# 1/1 [==============================] - 18s 18s/step
# 2/2 [==============================] - 1s 373ms/step
# Starting batch... 11
# 1/1 [==============================] - 21s 21s/step
# 2/2 [==============================] - 1s 536ms/step
# Starting batch... 12
# 1/1 [==============================] - 27s 27s/step
# 2/2 [==============================] - 1s 408ms/step
# Starting batch... 13
# 1/1 [==============================] - 21s 21s/step
# 3/3 [==============================] - 1s 409ms/step
# Starting batch... 14
# 1/1 [==============================] - 21s 21s/step
# 2/2 [==============================] - 1s 436ms/step
# Starting batch... 15
# 1/1 [==============================] - 21s 21s/step
# 2/2 [==============================] - 1s 420ms/step
# Starting batch... 16
# 1/1 [==============================] - 25s 25s/step
# 2/2 [==============================] - 1s 499ms/step
# Starting batch... 17
# 1/1 [==============================] - 23s 23s/step
# 2/2 [==============================] - 1s 457ms/step
# Starting batch... 18
# 1/1 [==============================] - 22s 22s/step
# 2/2 [==============================] - 1s 410ms/step
# Starting batch... 19
# 1/1 [==============================] - 21s 21s/step
# 2/2 [==============================] - 1s 454ms/step
# Starting batch... 20
# 1/1 [==============================] - 26s 26s/step
# 2/2 [==============================] - 1s 477ms/step
# Starting batch... 21
# 1/1 [==============================] - 35s 35s/step
# 2/2 [==============================] - 1s 432ms/step
# Starting batch... 22
# 1/1 [==============================] - 21s 21s/step
# 2/2 [==============================] - 1s 440ms/step
# Starting batch... 23
# 1/1 [==============================] - 22s 22s/step
# 2/2 [==============================] - 1s 425ms/step
# Starting batch... 24
# 1/1 [==============================] - 22s 22s/step
# 2/2 [==============================] - 1s 358ms/step
# Starting batch... 25
# 1/1 [==============================] - 37s 37s/step
# 2/2 [==============================] - 1s 434ms/step
# Starting batch... 26
# 1/1 [==============================] - 25s 25s/step
# 2/2 [==============================] - 1s 424ms/step
# Starting batch... 27
# 1/1 [==============================] - 22s 22s/step
# 2/2 [==============================] - 1s 429ms/step
# Starting batch... 28
# 1/1 [==============================] - 22s 22s/step
# 2/2 [==============================] - 1s 448ms/step
# Starting batch... 29
# 1/1 [==============================] - 21s 21s/step
# 2/2 [==============================] - 1s 415ms/step
# Starting batch... 30
# 1/1 [==============================] - 29s 29s/step
# 2/2 [==============================] - 1s 384ms/step
# Starting batch... 31
# 1/1 [==============================] - 23s 23s/step
# 2/2 [==============================] - 1s 502ms/step
# Starting batch... 32
# 1/1 [==============================] - 22s 22s/step
# 2/2 [==============================] - 1s 459ms/step
# Finishing up...
# 1/1 [==============================] - 17s 17s/step
# 2/2 [==============================] - 1s 223ms/step
# 1/1 [==============================] - 17s 17s/step
# 2/2 [==============================] - 1s 222ms/step
# Time to OCR read all images in subdirectory: 14.8 min

# %%
df_results['filenum'] = df_results['filename'].str.replace('.png', '')
df_results['filenum'] = df_results['filenum'].astype('int')
df_results = df_results.sort_values('filenum').reset_index(drop=True)
print(len(df_results))
df_results.head(30)
# Out:
# 262
# <ipython-input-15-ea160e78dcbb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_results['filenum'] = df_results['filename'].str.replace('.png', '')
#    station_number year day_of_year hour minute second filename  filenum
# 0              03   66         339   19     05     26    5.png        5
# 1              03   66         339   19     05     43    6.png        6
# 2              03   66         339   19     06     oo    7.png        7
# 3              03   66         339   19     06     35    9.png        9
# 4              03   66         339   19     06     52   10.png       10
# 5              03   66         339   19     08     19   12.png       12
# 6              03   66         339   ig     os     36   13.png       13
# 7              03   66         339   19     06     54   14.png       14
# 8              03   66         339   1g     oo     11   15.png       15
# 9              03   66         339   19     09     28   16.png       16
# 10             03   66         339   19     09     45   17.png       17
# 11             03   66         339   ig     io     03   18.png       18
# 12             03   66         339   ig     io     20   19.png       19
# 13             03   66         339   19     10     31   20.png       20
# 14             03   66         339   19     1o     54   21.png       21
# 15             03   66         339   19     11     12   22.png       22
# 16             03   66         339   19     11     29   23.png       23
# 17             03   66         339   19     11     46   24.png       24
# 18             03   66         339   19     12     03   25.png       25
# 19             03   66         339   19     12     21   26.png       26
# 20             03   66         339   19     12     38   27.png       27
# 21             03   66         339   19     12     55   28.png       28
# 22             03   66         339   19     13     12   29.png       29
# 23             03   66         339   19     13     30   30.png       30
# 24             03   66         339   19     13     47   31.png       31
# 25             03   66         339   ig     ia     04   32.png       32
# 26             03   66         339   ia     iz     21   33.png       33
# 27             03   66         339   ig     ia     56   35.png       35
# 28             03   66         339   19     15     15   36.png       36
# 29             03   66         339   19     15     30   37.png       37

# %%
df_results.to_csv(resultDir + 'OCR_subdir_test.csv')

# %% [markdown]
# Remove rows with letters read:

# %%
df1 = df_results[~df_results['station_number'].str.contains("[a-zA-Z]")]
df1 = df1[~df1['year'].str.contains("[a-zA-Z]")]
df1 = df1[~df1['day_of_year'].str.contains("[a-zA-Z]")]
df1 = df1[~df1['hour'].str.contains("[a-zA-Z]")]
df1 = df1[~df1['minute'].str.contains("[a-zA-Z]")]
df1 = df1[~df1['second'].str.contains("[a-zA-Z]")]

# %%
print(len(df1))
df1.head()
# Out:
# 178
#   station_number year day_of_year hour minute second filename  filenum
# 0             03   66         339   19     05     26    5.png        5
# 1             03   66         339   19     05     43    6.png        6
# 3             03   66         339   19     06     35    9.png        9
# 4             03   66         339   19     06     52   10.png       10
# 5             03   66         339   19     08     19   12.png       12

# %%
print('Percent OCR read yield for test subdirectory: ' + str(round((len(df1)/len(img_fns))*100, 1)) + ' %')
# Out:
# Percent OCR read yield for test subdirectory: 58.6 %
