# %% [markdown]
# # Download Subdirectories From FTP II
#
# #### Updated: Dec 8, 2022

# %% [markdown]
# #

# %% [markdown]
# Run for continuous downloading of subdirectories, concurrent with processing of subdirectories.

# %%
import pandas as pd
import os
import shutil
import time
from datetime import datetime
import ftplib
from random import randrange

# %% [markdown]
# Set parameters:

# %%
user = 'Rav'
process_on_VDI = True
wait = 2 #in minutes
stop_loop_threshold = 2640 #max while loops to prevent infinite loop

# %% [markdown]
# Set directories:

# %%
rootDir_local = 'C:/Users/rnaidoo/Documents/Projects_data/Alouette_I/' #files on C:/ are not persistent on VDI
downloadingDir = rootDir_local + '01_downloading/'
downloadedDir = rootDir_local + '02_downloaded/'
if process_on_VDI:
    logDir = '//scientific/L-MP-Data/Massive files/Python/rnaidoo/Alouette_I/' #DO NOT CHANGE
else:
    logDir = rootDir_local + '05_result/'

# %% [markdown]
# #

# %% [markdown]
# #### Functions:

# %%
def move_images(old_dir, new_dir, roll, subdir, copy_to_other_drive=False):
    oldDir = old_dir + roll + '/' + subdir + '/'
    newDir = new_dir + roll + '/' + subdir + '/'
    os.makedirs(newDir, exist_ok=True)
    
    if copy_to_other_drive:
        for file in os.listdir(oldDir):
            shutil.copyfile(oldDir+file, newDir+file)
    else:
        for file in os.listdir(oldDir):
            os.rename(oldDir+file, newDir+file)
    
    shutil.rmtree(old_dir + roll + '/' + subdir + '/')
    if len(os.listdir(old_dir + roll + '/')) == 0:
        shutil.rmtree(old_dir + roll + '/')

# %%
def draw_random_subdir(roll, subdir_list, logDir):
    
    subdirectory = subdir_list[randrange(len(subdir_list))]
    
    #Check randomly-selected roll and subdirectory against the 'download_log'
    if os.path.exists(logDir + 'download_log.csv'):
        df_log = pd.read_csv(logDir + 'download_log.csv')
        df_search = df_log.loc[(df_log['Roll'] == roll) & (df_log['Subdirectory'] == subdirectory)]
        if len(df_search) > 0:
            print(roll + '/' + subdirectory + ' already downloaded!')
            return ''
        else:
            return subdirectory
    else:
        return subdirectory

# %%
def draw_random_subdir2(subdir_ids_list, logDir):
    
    subdir_id = subdir_ids_list[randrange(len(subdir_ids_list))]
    subdir_id_parts = subdir_id.split('_')
    roll = subdir_id_parts[0]
    subdirectory = subdir_id_parts[1]
    
    #Check randomly-selected roll and subdirectory against the 'download_log'
    if os.path.exists(logDir + 'download_log.csv'):
        df_log = pd.read_csv(logDir + 'download_log.csv')
        df_search = df_log.loc[(df_log['Roll'] == roll) & (df_log['Subdirectory'] == subdirectory)]
        if len(df_search) > 0:
            print(roll + '/' + subdirectory + ' already downloaded!')
            return ''
        else:
            return roll, subdirectory
    else:
        return roll, subdirectory

# %% [markdown]
# #

# %% [markdown]
# #### Check if subdirectory needs to be downloaded, then download random subdirectory:

# %%
stop_condition = False
stop_condition_counter = 0

while stop_condition == False:
    #Download a random subdirectory if '02_downloaded' is empty
    if len(os.listdir(downloadedDir)) == 0:
        # Connect to FTP Server
        HOSTNAME = "donnees-data.asc-csa.gc.ca"
        USERNAME = "Anonymous"
        PASSWORD = ""
        ftp = ftplib.FTP(HOSTNAME, USERNAME, PASSWORD)
        print('Connected to ftp server: ' + HOSTNAME)
        ftp_rootpath = '/users/OpenData_DonneesOuvertes/pub/AlouetteData/Alouette Data/'

        #Randomly draw roll and subdirectory (using draw_random_subdir2())
        df_inventory = pd.read_csv(logDir + 'image_inventory.csv')
        subdir_ids_tot = df_inventory['subdir_id'].unique()
        if os.path.exists(logDir + 'download_log.csv'):
            df_log = pd.read_csv(logDir + 'download_log.csv')
            subdir_ids_dl = df_log['subdir_id'].unique()
        else:
            subdir_ids_dl = []
        subdir_ids_rem = list(set(subdir_ids_tot) - set(subdir_ids_dl))
        roll, subdirectory = draw_random_subdir2(subdir_ids_list=subdir_ids_rem, logDir=logDir)

        #Set directories
        saveDir = downloadingDir + roll + '/' + subdirectory + '/'
        os.makedirs(saveDir, exist_ok=True)
        ftp.cwd(ftp_rootpath + '/' + roll + '/' + subdirectory + '/')

        start = time.time()
        n_dl = len(ftp.nlst())
        print('')
        print('Downloading ' + roll + '/' + subdirectory + '/ subdirectory ('  + str(n_dl) + ' images, ' + str(len(subdir_ids_rem)-1) + ' subdirectories to go)')
        for file in ftp.nlst():
            local_file = open(saveDir + file, "wb")
            ftp.retrbinary("RETR " + file, local_file.write)
            local_file.close()
            #print('Downloaded: ' + file)
        end = time.time()
        t = end - start
        print('Download time for subdirectory: ' + str(round(t/60, 1)) + ' min')
        print('')

        #Record subdirectory name in download_log
        df_result = pd.DataFrame({
            'Roll': roll,
            'Subdirectory': subdirectory,
            'Images_downloaded': n_dl,
            'Download_time': t,
            'Download_timestamp': datetime.fromtimestamp(end),
            'User': user,
            'subdir_id': roll + '_' + subdirectory
        }, index=[0])
        if os.path.exists(logDir + 'download_log.csv'):
            df_log = pd.read_csv(logDir + 'download_log.csv')
            df_update = pd.concat([df_log, df_result], axis=0, ignore_index=True)
            df_update.to_csv(logDir + 'download_log.csv', index=False)
        else:
            df_result.to_csv(logDir + 'download_log.csv', index=False)

        #Backup 'download_log' (10% of the time)
        if randrange(10) == 7:
            df_log = pd.read_csv(logDir + 'download_log.csv')
            datetime_str = datetime.now().strftime("%Y%m%d_%Hh%M")
            os.makedirs(logDir + 'backups/', exist_ok=True)
            df_log.to_csv(logDir + 'backups/' + 'download_log-' + datetime_str + '.csv', index=False)

        #Move fully downloaded subdirectory to '02_processing' folder
        move_images(old_dir=downloadingDir, new_dir=downloadedDir, roll=roll, subdir=subdirectory)
        
        stop_condition_counter += 1
    
    else:
        #Wait
        print('Wait ' + str(wait) + ' min')
        time.sleep(wait*60)
    
    
    #Check stop conditions
    if len(subdir_ids_rem) == 1:
        print('Stop!')
        stop_condition = True
    if stop_condition_counter == stop_loop_threshold:
        print('Stop!')
        stop_condition = True
# Out:
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1345-18B/ subdirectory (341 images, 2145 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/926-B/ subdirectory (413 images, 2144 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1371-7B/ subdirectory (301 images, 2143 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2466-8A/ subdirectory (307 images, 2142 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/325/ subdirectory (436 images, 2141 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3069-13B/ subdirectory (344 images, 2140 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/951-B/ subdirectory (391 images, 2139 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3044-13B/ subdirectory (350 images, 2138 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3423-43A/ subdirectory (311 images, 2137 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1702-9B/ subdirectory (325 images, 2136 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2777-12A/ subdirectory (341 images, 2135 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/519/ subdirectory (401 images, 2134 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/406/ subdirectory (348 images, 2133 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/337/ subdirectory (386 images, 2132 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1963-3A/ subdirectory (346 images, 2131 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207908F/574/ subdirectory (429 images, 2130 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1896-9B/ subdirectory (353 images, 2129 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2393-7A/ subdirectory (281 images, 2128 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1822-9B/ subdirectory (345 images, 2127 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/544/ subdirectory (423 images, 2126 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1206-1B/ subdirectory (394 images, 2125 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3393-13A/ subdirectory (308 images, 2124 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/762-B/ subdirectory (397 images, 2123 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3528-50A/ subdirectory (271 images, 2122 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3658-38A/ subdirectory (267 images, 2121 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1126-B/ subdirectory (319 images, 2120 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2631-1A/ subdirectory (335 images, 2119 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1619-4A/ subdirectory (344 images, 2118 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2873-43B/ subdirectory (319 images, 2117 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207968/1253-13B/ subdirectory (314 images, 2116 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2435-3A/ subdirectory (343 images, 2115 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207908F/606/ subdirectory (385 images, 2114 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2794-6A/ subdirectory (330 images, 2113 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3083-13B/ subdirectory (340 images, 2112 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2366-7A/ subdirectory (302 images, 2111 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1874-1B/ subdirectory (349 images, 2110 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/772-A/ subdirectory (379 images, 2109 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/545/ subdirectory (397 images, 2108 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2932-43B/ subdirectory (324 images, 2107 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3551-43A/ subdirectory (313 images, 2106 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1116-B/ subdirectory (382 images, 2105 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/734/ subdirectory (306 images, 2104 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3333-38A/ subdirectory (316 images, 2103 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1700-9B/ subdirectory (366 images, 2102 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1663-18B/ subdirectory (351 images, 2101 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/992-B/ subdirectory (391 images, 2100 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2437-1B/ subdirectory (361 images, 2099 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1332-18B/ subdirectory (343 images, 2098 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207968/1266-5A/ subdirectory (334 images, 2097 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2543-5B/ subdirectory (349 images, 2096 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2567-5B/ subdirectory (358 images, 2095 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2663-15B/ subdirectory (345 images, 2094 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3578-19A/ subdirectory (331 images, 2093 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1937-3A/ subdirectory (352 images, 2092 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3647-15a/ subdirectory (327 images, 2091 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2358-7A/ subdirectory (357 images, 2090 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2216-1A/ subdirectory (346 images, 2089 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2775-7B/ subdirectory (323 images, 2088 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1204-1B/ subdirectory (348 images, 2087 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/522/ subdirectory (436 images, 2086 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3507-19A/ subdirectory (345 images, 2085 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3492-8A/ subdirectory (334 images, 2084 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2824-50B/ subdirectory (345 images, 2083 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1699-5A/ subdirectory (341 images, 2082 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3311-15A/ subdirectory (279 images, 2081 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3314-15A/ subdirectory (330 images, 2080 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2149-5B/ subdirectory (292 images, 2079 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/857-B/ subdirectory (378 images, 2078 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2864-43B/ subdirectory (323 images, 2077 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/336/ subdirectory (453 images, 2076 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/625/ subdirectory (374 images, 2075 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2081-5B/ subdirectory (350 images, 2074 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1583-1B/ subdirectory (354 images, 2073 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/653/ subdirectory (337 images, 2072 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2337-1B/ subdirectory (375 images, 2071 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3291-5A/ subdirectory (335 images, 2070 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2826-50B/ subdirectory (274 images, 2069 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3329-15A/ subdirectory (266 images, 2068 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2677-9A/ subdirectory (327 images, 2067 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1338-18B/ subdirectory (334 images, 2066 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1962-5B/ subdirectory (279 images, 2065 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2322-1B/ subdirectory (349 images, 2064 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/407/ subdirectory (398 images, 2063 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2546-5B/ subdirectory (319 images, 2062 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2624-8A/ subdirectory (320 images, 2061 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3270-3A/ subdirectory (308 images, 2060 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/530/ subdirectory (366 images, 2059 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/308/ subdirectory (375 images, 2058 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/520/ subdirectory (286 images, 2057 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2841-50B/ subdirectory (305 images, 2056 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2584-18B/ subdirectory (341 images, 2055 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2101-5B/ subdirectory (369 images, 2054 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/897-B/ subdirectory (336 images, 2053 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1954-5A/ subdirectory (277 images, 2052 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/969-A/ subdirectory (348 images, 2051 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3144-13B/ subdirectory (330 images, 2050 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2803-7A/ subdirectory (366 images, 2049 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/1022-B/ subdirectory (379 images, 2048 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3297-50A/ subdirectory (267 images, 2047 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/659/ subdirectory (359 images, 2046 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207908F/582/ subdirectory (384 images, 2045 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/640/ subdirectory (132 images, 2044 subdirectories to go)
# Download time for subdirectory: 0.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2585-8A/ subdirectory (324 images, 2043 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3425-50A/ subdirectory (311 images, 2042 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207979F/285/ subdirectory (449 images, 2041 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1640-18B/ subdirectory (314 images, 2040 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207967/1427-13B/ subdirectory (340 images, 2039 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/477/ subdirectory (400 images, 2038 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3078-13B/ subdirectory (326 images, 2037 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1697-5A/ subdirectory (289 images, 2036 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/531/ subdirectory (402 images, 2035 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2530-8A/ subdirectory (356 images, 2034 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2308-3A/ subdirectory (352 images, 2033 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3288-5A/ subdirectory (322 images, 2032 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/314/ subdirectory (412 images, 2031 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/315/ subdirectory (364 images, 2030 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2095-1A/ subdirectory (308 images, 2029 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1585-1B/ subdirectory (366 images, 2028 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3304-15A/ subdirectory (323 images, 2027 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3042-13B/ subdirectory (320 images, 2026 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2196-4B/ subdirectory (305 images, 2025 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207968/1211-5A/ subdirectory (390 images, 2024 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207967/1399-13B/ subdirectory (296 images, 2023 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3415-43A/ subdirectory (280 images, 2022 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3362-A38/ subdirectory (263 images, 2021 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3023-43A/ subdirectory (300 images, 2020 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1654-18B/ subdirectory (334 images, 2019 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207968/1228-5A/ subdirectory (392 images, 2018 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2647-15B/ subdirectory (313 images, 2017 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3495-8A/ subdirectory (303 images, 2016 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2694-13B/ subdirectory (307 images, 2015 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/912-B/ subdirectory (382 images, 2014 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2620-8A/ subdirectory (328 images, 2013 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/758-B/ subdirectory (403 images, 2012 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3256-50A/ subdirectory (333 images, 2011 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3286-5A/ subdirectory (253 images, 2010 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2854-50B/ subdirectory (358 images, 2009 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1365-7B/ subdirectory (297 images, 2008 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2180-4B/ subdirectory (321 images, 2007 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1713-9B/ subdirectory (347 images, 2006 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1840-1B/ subdirectory (338 images, 2005 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1456-13B/ subdirectory (320 images, 2004 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2118-1A/ subdirectory (336 images, 2003 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3629-19A/ subdirectory (294 images, 2002 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/500/ subdirectory (425 images, 2001 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2384-3A/ subdirectory (334 images, 2000 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2116-1A/ subdirectory (337 images, 1999 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2875-43B/ subdirectory (334 images, 1998 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3628-19A/ subdirectory (322 images, 1997 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/365/ subdirectory (408 images, 1996 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1677-13B/ subdirectory (315 images, 1995 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2342-1B/ subdirectory (337 images, 1994 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1950-5A/ subdirectory (281 images, 1993 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1350-7A/ subdirectory (311 images, 1992 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2792-6A/ subdirectory (362 images, 1991 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2832-50B/ subdirectory (304 images, 1990 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1835-3A/ subdirectory (355 images, 1989 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/346/ subdirectory (428 images, 1988 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/934-A/ subdirectory (391 images, 1987 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3522-43A/ subdirectory (308 images, 1986 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2087-5B/ subdirectory (331 images, 1985 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2862-50B/ subdirectory (338 images, 1984 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3422-43A/ subdirectory (211 images, 1983 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207908F/589/ subdirectory (409 images, 1982 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2599-18B/ subdirectory (317 images, 1981 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3062-13B/ subdirectory (303 images, 1980 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/904-B/ subdirectory (361 images, 1979 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/663/ subdirectory (372 images, 1978 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/670/ subdirectory (364 images, 1977 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1164-B/ subdirectory (396 images, 1976 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2570-18B/ subdirectory (326 images, 1975 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2339-7A/ subdirectory (268 images, 1974 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1614-18B/ subdirectory (382 images, 1973 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2330-7A/ subdirectory (341 images, 1972 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2769-4A/ subdirectory (239 images, 1971 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1911-4B/ subdirectory (265 images, 1970 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1847-18A/ subdirectory (338 images, 1969 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2676-13B/ subdirectory (320 images, 1968 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/761-A/ subdirectory (387 images, 1967 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 5 min
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/611/ subdirectory (398 images, 1966 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/429/ subdirectory (419 images, 1965 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2418-9A/ subdirectory (320 images, 1964 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2197-1A/ subdirectory (347 images, 1963 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/922-B/ subdirectory (386 images, 1962 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 5 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2939-43B/ subdirectory (302 images, 1961 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 5 min
