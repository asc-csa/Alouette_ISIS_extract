# %% [markdown]
# # Download Subdirectories From FTP II
#
# #### Updated: Jan 6, 2023

# %% [markdown]
# #

# %% [markdown]
# Run for continuous downloading of subdirectories, concurrent with processing of subdirectories.

# %%
import pandas as pd
import os
import shutil
import time
from datetime import datetime
import ftplib
from random import randrange

# %% [markdown]
# Set parameters:

# %%
user = 'Rav'
process_on_VDI = True
wait = 4 #in minutes
stop_loop_threshold = 2640 #max while loops to prevent infinite loop

# %% [markdown]
# Set directories:

# %%
rootDir_local = 'C:/Users/rnaidoo/Documents/Projects_data/Alouette_I/' #files on C:/ are not persistent on VDI
downloadingDir = rootDir_local + '01_downloading/'
downloadedDir = rootDir_local + '02_downloaded/'
if process_on_VDI:
    logDir = 'L:/DATA/Alouette_I/06_log/' #DO NOT CHANGE
else:
    logDir = rootDir_local + '06_log/'

# %% [markdown]
# #

# %% [markdown]
# #### Functions:

# %%
def move_images(old_dir, new_dir, roll, subdir, copy_to_other_drive=False):
    oldDir = old_dir + roll + '/' + subdir + '/'
    newDir = new_dir + roll + '/' + subdir + '/'
    os.makedirs(newDir, exist_ok=True)
    
    if copy_to_other_drive:
        for file in os.listdir(oldDir):
            shutil.copyfile(oldDir+file, newDir+file)
    else:
        for file in os.listdir(oldDir):
            os.rename(oldDir+file, newDir+file)
    
    shutil.rmtree(old_dir + roll + '/' + subdir + '/')
    if len(os.listdir(old_dir + roll + '/')) == 0:
        shutil.rmtree(old_dir + roll + '/')

# %%
def draw_random_subdir(roll, subdir_list, logDir):
    
    subdirectory = subdir_list[randrange(len(subdir_list))]
    
    #Check randomly-selected roll and subdirectory against the 'download_log'
    if os.path.exists(logDir + 'download_log.csv'):
        df_log = pd.read_csv(logDir + 'download_log.csv')
        df_search = df_log.loc[(df_log['Roll'] == roll) & (df_log['Subdirectory'] == subdirectory)]
        if len(df_search) > 0:
            print(roll + '/' + subdirectory + ' already downloaded!')
            return ''
        else:
            return subdirectory
    else:
        return subdirectory

# %%
def draw_random_subdir2(subdir_ids_list, logDir):
    
    subdir_id = subdir_ids_list[randrange(len(subdir_ids_list))]
    subdir_id_parts = subdir_id.split('_')
    roll = subdir_id_parts[0]
    subdirectory = subdir_id_parts[1]
    
    #Check randomly-selected roll and subdirectory against the 'download_log'
    if os.path.exists(logDir + 'download_log.csv'):
        df_log = pd.read_csv(logDir + 'download_log.csv')
        df_search = df_log.loc[(df_log['Roll'] == roll) & (df_log['Subdirectory'] == subdirectory)]
        if len(df_search) > 0:
            print(roll + '/' + subdirectory + ' already downloaded!')
            return ''
        else:
            return roll, subdirectory
    else:
        return roll, subdirectory

# %% [markdown]
# #

# %% [markdown]
# #### Check if subdirectory needs to be downloaded, then download random subdirectory:

# %%
stop_condition = False
stop_condition_counter = 0

while stop_condition == False:
    #Download a random subdirectory if '02_downloaded' is empty
    if len(os.listdir(downloadedDir)) == 0:
        # Connect to FTP Server
        HOSTNAME = "donnees-data.asc-csa.gc.ca"
        USERNAME = "Anonymous"
        PASSWORD = ""
        ftp = ftplib.FTP(HOSTNAME, USERNAME, PASSWORD)
        print('Connected to ftp server: ' + HOSTNAME)
        ftp_rootpath = '/users/OpenData_DonneesOuvertes/pub/AlouetteData/Alouette Data/'

        #Randomly draw roll and subdirectory (using draw_random_subdir2())
        df_inventory = pd.read_csv(logDir + 'image_inventory.csv')
        subdir_ids_tot = df_inventory['subdir_id'].unique()
        if os.path.exists(logDir + 'download_log.csv'):
            df_log = pd.read_csv(logDir + 'download_log.csv')
            subdir_ids_dl = df_log['subdir_id'].unique()
        else:
            subdir_ids_dl = []
        subdir_ids_rem = list(set(subdir_ids_tot) - set(subdir_ids_dl))
        roll, subdirectory = draw_random_subdir2(subdir_ids_list=subdir_ids_rem, logDir=logDir)

        #Set directories
        saveDir = downloadingDir + roll + '/' + subdirectory + '/'
        os.makedirs(saveDir, exist_ok=True)
        ftp.cwd(ftp_rootpath + '/' + roll + '/' + subdirectory + '/')

        start = time.time()
        n_dl = len(ftp.nlst())
        print('')
        print('Downloading ' + roll + '/' + subdirectory + '/ subdirectory ('  + str(n_dl) + ' images, ' + str(len(subdir_ids_rem)-1) + ' subdirectories to go)')
        for file in ftp.nlst():
            local_file = open(saveDir + file, "wb")
            ftp.retrbinary("RETR " + file, local_file.write)
            local_file.close()
            #print('Downloaded: ' + file)
        end = time.time()
        t = end - start
        print('Download time for subdirectory: ' + str(round(t/60, 1)) + ' min')
        print('')

        #Record subdirectory name in download_log
        df_result = pd.DataFrame({
            'Roll': roll,
            'Subdirectory': subdirectory,
            'Images_downloaded': n_dl,
            'Download_time': t,
            'Download_timestamp': datetime.fromtimestamp(end),
            'User': user,
            'subdir_id': roll + '_' + subdirectory
        }, index=[0])
        if os.path.exists(logDir + 'download_log.csv'):
            df_log = pd.read_csv(logDir + 'download_log.csv')
            df_update = pd.concat([df_log, df_result], axis=0, ignore_index=True)
            df_update.to_csv(logDir + 'download_log.csv', index=False)
        else:
            df_result.to_csv(logDir + 'download_log.csv', index=False)

        #Backup 'download_log' (10% of the time)
        if randrange(10) == 7:
            df_log = pd.read_csv(logDir + 'download_log.csv')
            datetime_str = datetime.now().strftime("%Y%m%d_%Hh%M")
            os.makedirs(logDir + 'backups/', exist_ok=True)
            df_log.to_csv(logDir + 'backups/' + 'download_log-' + datetime_str + '.csv', index=False)

        #Move fully downloaded subdirectory to '02_processing' folder
        move_images(old_dir=downloadingDir, new_dir=downloadedDir, roll=roll, subdir=subdirectory)
        
        stop_condition_counter += 1
    
    else:
        #Wait
        print('Wait ' + str(wait) + ' min')
        subdir_ids_rem = []
        time.sleep(wait*60)
    
    
    #Check stop conditions
    if len(subdir_ids_rem) == 1:
        print('Stop!')
        stop_condition = True
    if stop_condition_counter == stop_loop_threshold:
        print('Stop!')
        stop_condition = True
# Out:
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3576-19A/ subdirectory (333 images, 615 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3020-43A/ subdirectory (331 images, 614 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2327-1A/ subdirectory (277 images, 613 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3317-15A/ subdirectory (315 images, 612 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1591-1B/ subdirectory (345 images, 611 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/860-B/ subdirectory (356 images, 610 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/395/ subdirectory (314 images, 609 subdirectories to go)
# Download time for subdirectory: 0.8 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1696-9B/ subdirectory (318 images, 608 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2409-7A/ subdirectory (350 images, 607 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2109-1A/ subdirectory (305 images, 606 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2703-13B/ subdirectory (331 images, 605 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/869-B/ subdirectory (289 images, 604 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3358-38A/ subdirectory (308 images, 603 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/724/ subdirectory (357 images, 602 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2411-7A/ subdirectory (385 images, 601 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/908-B/ subdirectory (392 images, 600 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1627-4A/ subdirectory (345 images, 599 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3589-50A/ subdirectory (342 images, 598 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2096-5B/ subdirectory (343 images, 597 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3345-38A/ subdirectory (305 images, 596 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2452-8A/ subdirectory (329 images, 595 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/325/ subdirectory (436 images, 594 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1706-9B/ subdirectory (357 images, 593 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2905-43B/ subdirectory (320 images, 592 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2530-8A/ subdirectory (356 images, 591 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2585-8A/ subdirectory (324 images, 590 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1840-1B/ subdirectory (338 images, 589 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/332/ subdirectory (399 images, 588 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2599-18B/ subdirectory (317 images, 587 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1360-5A/ subdirectory (327 images, 586 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3162-13B/ subdirectory (312 images, 585 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1106-B/ subdirectory (371 images, 584 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1944-3A/ subdirectory (226 images, 583 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2392-7A/ subdirectory (324 images, 582 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1451-5A/ subdirectory (324 images, 581 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2930-50B/ subdirectory (335 images, 580 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1624-18B/ subdirectory (349 images, 579 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2692-13B/ subdirectory (330 images, 578 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1367-7B/ subdirectory (347 images, 577 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2322-1B/ subdirectory (349 images, 576 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/766-B/ subdirectory (351 images, 575 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3180-13B/ subdirectory (309 images, 574 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3290-5A/ subdirectory (282 images, 573 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3326-15A/ subdirectory (280 images, 572 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207908F/585/ subdirectory (413 images, 571 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/954-A/ subdirectory (396 images, 570 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3112-8A/ subdirectory (257 images, 569 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3122-13B/ subdirectory (316 images, 568 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/370/ subdirectory (435 images, 567 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/683/ subdirectory (311 images, 566 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/481/ subdirectory (424 images, 565 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3172-14A/ subdirectory (300 images, 564 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2205-1A/ subdirectory (357 images, 563 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207967/1439-5A/ subdirectory (341 images, 562 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/737/ subdirectory (228 images, 561 subdirectories to go)
# Download time for subdirectory: 0.7 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3083-13B/ subdirectory (340 images, 560 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1593-12A/ subdirectory (323 images, 559 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3658-38A/ subdirectory (267 images, 558 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1675-13/ subdirectory (334 images, 557 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2807-7A/ subdirectory (353 images, 556 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1340-18B/ subdirectory (350 images, 555 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3620-43A/ subdirectory (340 images, 554 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3034-50A/ subdirectory (324 images, 553 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2055-1A/ subdirectory (282 images, 552 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/715/ subdirectory (379 images, 551 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/882-A/ subdirectory (339 images, 550 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3144-13B/ subdirectory (330 images, 549 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2882-43B/ subdirectory (313 images, 548 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3385-A13/ subdirectory (316 images, 547 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/634/ subdirectory (370 images, 546 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2851-50B/ subdirectory (325 images, 545 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/1002-B/ subdirectory (357 images, 544 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/691/ subdirectory (371 images, 543 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1986-5B/ subdirectory (291 images, 542 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/432/ subdirectory (386 images, 541 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/632/ subdirectory (399 images, 540 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3283-5A/ subdirectory (249 images, 539 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/699/ subdirectory (349 images, 538 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2063-3A/ subdirectory (310 images, 537 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3526-A50/ subdirectory (314 images, 536 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/733/ subdirectory (389 images, 535 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/734/ subdirectory (306 images, 534 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3617-43A-2/ subdirectory (313 images, 533 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1651-18B/ subdirectory (341 images, 532 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1614-18B/ subdirectory (382 images, 531 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2147-5B/ subdirectory (317 images, 530 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/685/ subdirectory (398 images, 529 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/725/ subdirectory (380 images, 528 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3353-38A/ subdirectory (297 images, 527 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2429-12A 2/ subdirectory (364 images, 526 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2563-5B/ subdirectory (340 images, 525 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2769-4A/ subdirectory (239 images, 524 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/500/ subdirectory (425 images, 523 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/456/ subdirectory (444 images, 522 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1619-4A/ subdirectory (344 images, 521 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/374/ subdirectory (411 images, 520 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3386-13A/ subdirectory (289 images, 519 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2385-1B/ subdirectory (298 images, 518 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3594-50A/ subdirectory (274 images, 517 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1647-4A/ subdirectory (290 images, 516 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/451/ subdirectory (426 images, 515 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3259-50A/ subdirectory (258 images, 514 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3552-43A-2/ subdirectory (299 images, 513 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2111-5B/ subdirectory (332 images, 512 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3540-12A/ subdirectory (324 images, 511 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/740/ subdirectory (381 images, 510 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1913-4B/ subdirectory (257 images, 509 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1594-1B/ subdirectory (345 images, 508 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1863-1B/ subdirectory (356 images, 507 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3510-19A/ subdirectory (334 images, 506 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/858-B/ subdirectory (368 images, 505 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/923-B/ subdirectory (424 images, 504 subdirectories to go)
# Download time for subdirectory: 2.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/925-A/ subdirectory (334 images, 503 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1099-B/ subdirectory (399 images, 502 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1818-9B/ subdirectory (369 images, 501 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2169-1A/ subdirectory (332 images, 500 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3422-43A/ subdirectory (211 images, 499 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2860-50B/ subdirectory (287 images, 498 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/910-B/ subdirectory (346 images, 497 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1956-9B/ subdirectory (338 images, 496 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2292-8B/ subdirectory (334 images, 495 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/458/ subdirectory (407 images, 494 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3134-13B/ subdirectory (176 images, 493 subdirectories to go)
# Download time for subdirectory: 0.8 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1587-1B/ subdirectory (339 images, 492 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2060-43A/ subdirectory (281 images, 491 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2149-5B/ subdirectory (292 images, 490 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1724-1A/ subdirectory (293 images, 489 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207978F/346/ subdirectory (428 images, 488 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1745-9/ subdirectory (316 images, 487 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/639/ subdirectory (372 images, 486 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1183-1B/ subdirectory (386 images, 485 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2387-7A/ subdirectory (344 images, 484 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2798-6A/ subdirectory (337 images, 483 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/899-IIB/ subdirectory (314 images, 482 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2125-3A/ subdirectory (316 images, 481 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/457/ subdirectory (440 images, 480 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/371/ subdirectory (389 images, 479 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2928-43B/ subdirectory (311 images, 478 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2356-1B/ subdirectory (374 images, 477 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1682-9B/ subdirectory (375 images, 476 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/769-B/ subdirectory (363 images, 475 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2566-8A/ subdirectory (326 images, 474 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2778-12A/ subdirectory (317 images, 473 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1612-18B/ subdirectory (341 images, 472 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1707-5A/ subdirectory (368 images, 471 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2291-3A/ subdirectory (349 images, 470 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3334-38A/ subdirectory (251 images, 469 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207967/1421-8A/ subdirectory (280 images, 468 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/704/ subdirectory (386 images, 467 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3035-50A/ subdirectory (324 images, 466 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/937-B/ subdirectory (305 images, 465 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2195-1A/ subdirectory (345 images, 464 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/510/ subdirectory (433 images, 463 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3030-50A/ subdirectory (293 images, 462 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1639-4A/ subdirectory (360 images, 461 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3502-A19/ subdirectory (323 images, 460 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/994-B/ subdirectory (375 images, 459 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1202-1B/ subdirectory (372 images, 458 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3177-14A/ subdirectory (274 images, 457 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/420/ subdirectory (346 images, 456 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2462-8A/ subdirectory (342 images, 455 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/508/ subdirectory (417 images, 454 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1967-1A/ subdirectory (306 images, 453 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1955-5A/ subdirectory (290 images, 452 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2820-7A/ subdirectory (324 images, 451 subdirectories to go)
# Download time for subdirectory: 0.8 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2806-7A/ subdirectory (296 images, 450 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2538-5B/ subdirectory (332 images, 449 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/738/ subdirectory (413 images, 448 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207967/1434-13B/ subdirectory (354 images, 447 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/920-B/ subdirectory (383 images, 446 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/663/ subdirectory (372 images, 445 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1148-B/ subdirectory (400 images, 444 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3356-A38/ subdirectory (318 images, 443 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1142-B/ subdirectory (402 images, 442 subdirectories to go)
# Download time for subdirectory: 2.0 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1659-13A/ subdirectory (336 images, 441 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1839-1B/ subdirectory (333 images, 440 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3127-13B/ subdirectory (343 images, 439 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3281-5A/ subdirectory (296 images, 438 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1468-5A/ subdirectory (338 images, 437 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/950-B/ subdirectory (338 images, 436 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1144-B/ subdirectory (396 images, 435 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1958-5A/ subdirectory (299 images, 434 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2914-43B/ subdirectory (305 images, 433 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3014-43A/ subdirectory (256 images, 432 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3163-14A/ subdirectory (321 images, 431 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3411-43A/ subdirectory (325 images, 430 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207908F/578/ subdirectory (364 images, 429 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3539-12A/ subdirectory (317 images, 428 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207979F/306/ subdirectory (397 images, 427 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2061-1A/ subdirectory (293 images, 426 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2050-1A/ subdirectory (305 images, 425 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1590-12A/ subdirectory (307 images, 424 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1488-1B/ subdirectory (353 images, 423 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1359-7B/ subdirectory (296 images, 422 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2088-1A/ subdirectory (364 images, 421 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1744-9/ subdirectory (302 images, 420 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/429/ subdirectory (419 images, 419 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/753-A/ subdirectory (403 images, 418 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3518-15A/ subdirectory (345 images, 417 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3559-43A/ subdirectory (324 images, 416 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/744-A/ subdirectory (399 images, 415 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1981-5A/ subdirectory (289 images, 414 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207942/1972-1A/ subdirectory (197 images, 413 subdirectories to go)
# Download time for subdirectory: 0.8 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207968/1224-9B/ subdirectory (393 images, 412 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2591-5B/ subdirectory (344 images, 411 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/786-A/ subdirectory (397 images, 410 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1501-1B/ subdirectory (293 images, 409 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2623-18B/ subdirectory (338 images, 408 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/381/ subdirectory (356 images, 407 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/514/ subdirectory (439 images, 406 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2056-1A/ subdirectory (297 images, 405 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/431/ subdirectory (390 images, 404 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1909-18A/ subdirectory (337 images, 403 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/401/ subdirectory (392 images, 402 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2707-9A/ subdirectory (327 images, 401 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2797-6A/ subdirectory (308 images, 400 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207816/3393-13A/ subdirectory (308 images, 399 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1716-1A/ subdirectory (324 images, 398 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3119-13B/ subdirectory (323 images, 397 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2574-8A/ subdirectory (334 images, 396 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3057-13B/ subdirectory (316 images, 395 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/671/ subdirectory (383 images, 394 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1477-5A/ subdirectory (344 images, 393 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1482-1B/ subdirectory (315 images, 392 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1822-9B/ subdirectory (345 images, 391 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/847-B/ subdirectory (341 images, 390 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/447/ subdirectory (408 images, 389 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1629-4A/ subdirectory (346 images, 388 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/877-A/ subdirectory (346 images, 387 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3024-43A/ subdirectory (72 images, 386 subdirectories to go)
# Download time for subdirectory: 0.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/532/ subdirectory (368 images, 385 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2657-15B/ subdirectory (295 images, 384 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207953/2658-1A/ subdirectory (336 images, 383 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3579-19A-2/ subdirectory (336 images, 382 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207968/1230-5A/ subdirectory (408 images, 381 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1690-5A/ subdirectory (368 images, 380 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207962/1490-1B/ subdirectory (297 images, 379 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207967/1405-13B/ subdirectory (347 images, 378 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/542/ subdirectory (378 images, 377 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/727/ subdirectory (392 images, 376 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207958/2815-7A/ subdirectory (348 images, 375 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1670-9B/ subdirectory (323 images, 374 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3601-50A/ subdirectory (255 images, 373 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# ...
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/782-A/ subdirectory (358 images, 354 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3330-38A/ subdirectory (328 images, 353 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3297-50A/ subdirectory (267 images, 352 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207938/927-A/ subdirectory (394 images, 351 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2637-1A/ subdirectory (322 images, 350 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3642-15A/ subdirectory (394 images, 349 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3062-13B/ subdirectory (303 images, 348 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1168-5A/ subdirectory (378 images, 347 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1916-4B/ subdirectory (292 images, 346 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/622/ subdirectory (370 images, 345 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207979F/286/ subdirectory (343 images, 344 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207824/3138-14A/ subdirectory (295 images, 343 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/533/ subdirectory (405 images, 342 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2319-3A/ subdirectory (330 images, 341 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2888-43B/ subdirectory (332 images, 340 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207965/1634-18B/ subdirectory (359 images, 339 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2464-8A/ subdirectory (324 images, 338 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2337-1B/ subdirectory (375 images, 337 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3531-5A/ subdirectory (311 images, 336 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1844-18A/ subdirectory (307 images, 335 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207908F/598/ subdirectory (310 images, 334 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207939/902-A/ subdirectory (389 images, 333 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207929F/453/ subdirectory (395 images, 332 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3558-43A/ subdirectory (285 images, 331 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2592-8A/ subdirectory (329 images, 330 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207970/1382-8A/ subdirectory (331 images, 329 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/503/ subdirectory (404 images, 328 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207844/2902-43B/ subdirectory (297 images, 327 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207964/1577-3A/ subdirectory (311 images, 326 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207907F/537/ subdirectory (412 images, 325 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/1023-A/ subdirectory (418 images, 324 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3040-13A/ subdirectory (318 images, 323 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3312-15A/ subdirectory (279 images, 322 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1830-13B/ subdirectory (246 images, 321 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207954/2193-4B/ subdirectory (351 images, 320 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/672/ subdirectory (383 images, 319 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207940F/422/ subdirectory (390 images, 318 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207841/3107-13B/ subdirectory (321 images, 317 subdirectories to go)
# Download time for subdirectory: 2.0 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1163-5A/ subdirectory (387 images, 316 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/1009-A/ subdirectory (391 images, 315 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207957/2645-1A/ subdirectory (339 images, 314 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1807-5B/ subdirectory (325 images, 313 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207951/2463-1B/ subdirectory (310 images, 312 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3288-5A/ subdirectory (322 images, 311 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1848-1B/ subdirectory (309 images, 310 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207842/3304-15A/ subdirectory (323 images, 309 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207974/774-A/ subdirectory (411 images, 308 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1922-3A/ subdirectory (184 images, 307 subdirectories to go)
# Download time for subdirectory: 0.8 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207960/2580-8a/ subdirectory (340 images, 306 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207955/2863-50B/ subdirectory (264 images, 305 subdirectories to go)
# Download time for subdirectory: 1.0 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1130-B/ subdirectory (391 images, 304 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2083-5B/ subdirectory (343 images, 303 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1837-1B/ subdirectory (340 images, 302 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207979F/304/ subdirectory (495 images, 301 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207815/3541-12A/ subdirectory (305 images, 300 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/1014-B/ subdirectory (368 images, 299 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207832/3654-8A/ subdirectory (306 images, 298 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207946/1825-1B/ subdirectory (343 images, 297 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2314-1B/ subdirectory (332 images, 296 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3582-19A/ subdirectory (356 images, 295 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2138-5B/ subdirectory (307 images, 294 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2365-7A/ subdirectory (334 images, 293 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207943/2076-3A/ subdirectory (348 images, 292 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1731-3A/ subdirectory (365 images, 291 subdirectories to go)
# Download time for subdirectory: 1.8 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207947/1898-9B/ subdirectory (306 images, 290 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207956/2368-1B/ subdirectory (332 images, 289 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1157-B/ subdirectory (335 images, 288 subdirectories to go)
# Download time for subdirectory: 1.6 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2142-5B/ subdirectory (309 images, 287 subdirectories to go)
# Download time for subdirectory: 1.3 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3319-15A/ subdirectory (302 images, 286 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1172-13B/ subdirectory (386 images, 285 subdirectories to go)
# Download time for subdirectory: 1.7 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207930F/621/ subdirectory (377 images, 284 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207980/987-A/ subdirectory (131 images, 283 subdirectories to go)
# Download time for subdirectory: 0.5 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207909F/719/ subdirectory (351 images, 282 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207823/3583-37A/ subdirectory (215 images, 281 subdirectories to go)
# Download time for subdirectory: 0.9 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207948/1741-13/ subdirectory (249 images, 280 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207840/3039-50A/ subdirectory (314 images, 279 subdirectories to go)
# Download time for subdirectory: 1.4 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207966/1155-A/ subdirectory (266 images, 278 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3362-A38/ subdirectory (263 images, 277 subdirectories to go)
# Download time for subdirectory: 1.1 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207975/1127-A/ subdirectory (316 images, 276 subdirectories to go)
# Download time for subdirectory: 1.2 min
#
# Wait 4 min
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207959/2329-1B/ subdirectory (344 images, 275 subdirectories to go)
# Download time for subdirectory: 1.5 min
#
# Wait 4 min
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207821/3343-38A/ subdirectory (320 images, 274 subdirectories to go)

# %% [markdown]
# #

# %% [markdown]
# #### Download a particular subdirectory:

# %%
roll = 'R014207949'
subdirectory = '2114-1A'

# %%
# Connect to FTP Server
HOSTNAME = "donnees-data.asc-csa.gc.ca"
USERNAME = "Anonymous"
PASSWORD = ""
ftp = ftplib.FTP(HOSTNAME, USERNAME, PASSWORD)
print('Connected to ftp server: ' + HOSTNAME)
ftp_rootpath = '/users/OpenData_DonneesOuvertes/pub/AlouetteData/Alouette Data/'

#Set directories
saveDir = downloadingDir + roll + '/' + subdirectory + '/'
os.makedirs(saveDir, exist_ok=True)
ftp.cwd(ftp_rootpath + '/' + roll + '/' + subdirectory + '/')

start = time.time()
n_dl = len(ftp.nlst())
print('')
print('Downloading ' + roll + '/' + subdirectory + '/ subdirectory ('  + str(n_dl) + ' images)')
for file in ftp.nlst():
    local_file = open(saveDir + file, "wb")
    ftp.retrbinary("RETR " + file, local_file.write)
    local_file.close()
    #print('Downloaded: ' + file)
end = time.time()
t = end - start
print('Download time for subdirectory: ' + str(round(t/60, 1)) + ' min')
print('')

#Record subdirectory name in download_log
df_result = pd.DataFrame({
    'Roll': roll,
    'Subdirectory': subdirectory,
    'Images_downloaded': n_dl,
    'Download_time': t,
    'Download_timestamp': datetime.fromtimestamp(end),
    'User': user,
    'subdir_id': roll + '_' + subdirectory
}, index=[0])
if os.path.exists(logDir + 'download_log.csv'):
    df_log = pd.read_csv(logDir + 'download_log.csv')
    df_update = pd.concat([df_log, df_result], axis=0, ignore_index=True)
    df_update.to_csv(logDir + 'download_log.csv', index=False)
else:
    df_result.to_csv(logDir + 'download_log.csv', index=False)

#Backup 'download_log' (10% of the time)
if randrange(10) == 7:
    df_log = pd.read_csv(logDir + 'download_log.csv')
    datetime_str = datetime.now().strftime("%Y%m%d_%Hh%M")
    os.makedirs(logDir + 'backups/', exist_ok=True)
    df_log.to_csv(logDir + 'backups/' + 'download_log-' + datetime_str + '.csv', index=False)

#Move fully downloaded subdirectory to '02_processing' folder
move_images(old_dir=downloadingDir, new_dir=downloadedDir, roll=roll, subdir=subdirectory)
# Out:
# Connected to ftp server: donnees-data.asc-csa.gc.ca
#
# Downloading R014207949/2114-1A/ subdirectory (341 images)
# Download time for subdirectory: 1.4 min
