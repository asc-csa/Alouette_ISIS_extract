# %% [markdown]
# # Analyze Processing Quality
#
# #### Updated: Jan 6, 2023

# %% [markdown]
# #

# %% [markdown]
# Analyze the overall quality of the processing of the first batch of Alouette images. Determine that all subdirectories have been processed. Determine which subdirectories have the highest loss - are there any patterns? For instance, do certain rolls have high loss, or images from certain ground stations?

# %%
import pandas as pd
import numpy as np
import os

# %%
logDir = 'L:/DATA/Alouette_I/06_log/'

# %% [markdown]
# #

# %% [markdown]
# #### Determine outstanding subdirectories to process:

# %% [markdown]
# Remove duplicates from process_log:

# %%
df_process_log = pd.read_csv(logDir + 'process_log.csv')
print(len(df_process_log))
df_process_log.head()
# Out:
# 2922
#           Roll Subdirectory  Images_processed  Images_dot  Images_num  \
# 0  R014207978F          319               239         206           5
# 1   R014207966      1185-1B               386           0         383
# 2   R014207975       1108-B               363           0         347
# 3   R014207957      2631-1A               333           0         320
# 4   R014207966       1150-B               369           0         362
#
#    Images_loss  Images_outlier  Process_time           Process_timestamp User  \
# 0           11              17    259.625649  2022-12-15 23:28:15.951151  Rav
# 1            0               3   1415.449691  2022-12-15 23:51:57.608703  Rav
# 2            4              12    367.330205  2022-12-15 23:58:19.342118  Rav
# 3            4               9    607.819416  2022-12-16 00:08:43.220755  Rav
# 4            1               6    775.810147  2022-12-16 00:21:52.993215  Rav
#
#             subdir_id
# 0     R014207978F_319
# 1  R014207966_1185-1B
# 2   R014207975_1108-B
# 3  R014207957_2631-1A
# 4   R014207966_1150-B

# %%
df_p1 = df_process_log.sort_values('Process_timestamp', ascending=True)
df_p1 = df_p1.drop_duplicates(subset=['subdir_id'], keep='last') 
print(len(df_p1))
df_p1.head()
# Out:
# 2637
#           Roll Subdirectory  Images_processed  Images_dot  Images_num  \
# 1   R014207966      1185-1B               386           0         383
# 2   R014207975       1108-B               363           0         347
# 3   R014207957      2631-1A               333           0         320
# 4   R014207966       1150-B               369           0         362
# 5  R014207979F          288               421         345           3
#
#    Images_loss  Images_outlier  Process_time           Process_timestamp User  \
# 1            0               3   1415.449691  2022-12-15 23:51:57.608703  Rav
# 2            4              12    367.330205  2022-12-15 23:58:19.342118  Rav
# 3            4               9    607.819416  2022-12-16 00:08:43.220755  Rav
# 4            1               6    775.810147  2022-12-16 00:21:52.993215  Rav
# 5           23              50    157.020877  2022-12-16 00:24:43.050306  Rav
#
#             subdir_id
# 1  R014207966_1185-1B
# 2   R014207975_1108-B
# 3  R014207957_2631-1A
# 4   R014207966_1150-B
# 5     R014207979F_288

# %%
df_p1.tail()
# Out:
#              Roll Subdirectory  Images_processed  Images_dot  Images_num  \
# 2898  R014207907F          527                 0           0           0
# 2864  R014207909F          716                 0           0           0
# 2919  R014207929F          458                 0           0           0
# 2920   R014207955     2835-50B                 0           0           0
# 2921   R014207962      1505-1B                 0           0           0
#
#       Images_loss  Images_outlier  Process_time           Process_timestamp  \
# 2898            0               0      8.034927  2023-01-06 17:22:43.826910
# 2864            0               0      9.342925  2023-01-06 17:23:00.272846
# 2919            0               0     10.369817  2023-01-06 17:23:18.552994
# 2920            0               0     16.129880  2023-01-06 17:23:40.365107
# 2921            0               0      7.618111  2023-01-06 17:23:56.385944
#
#      User            subdir_id
# 2898  Rav      R014207907F_527
# 2864  Rav      R014207909F_716
# 2919  Rav      R014207929F_458
# 2920  Rav  R014207955_2835-50B
# 2921  Rav   R014207962_1505-1B

# %% [markdown]
# Look at duplicates from process_log:

# %%
df_p1_ = df_process_log[df_process_log.duplicated(subset=['subdir_id'], keep=False)]
df_p1_ = df_p1_.sort_values(['subdir_id', 'Process_timestamp'])
print(len(df_p1_))
df_p1_.head(10)
# Out:
# 331
#             Roll Subdirectory  Images_processed  Images_dot  Images_num  \
# 948   R014207816     3413-43A                 0           0           0
# 1069  R014207816     3413-43A               290           0         284
# 1524  R014207816     3413-43A               290           0         284
# 2712  R014207816     3413-43A                 0           0           0
# 2713  R014207816     3413-43A                 0           0           0
# 2715  R014207816     3413-43A                 0           0           0
# 2718  R014207816     3413-43A                 0           0           0
# 2722  R014207816     3413-43A                 0           0           0
# 2727  R014207816     3413-43A                 0           0           0
# 2733  R014207816     3413-43A                 0           0           0
#
#       Images_loss  Images_outlier  Process_time           Process_timestamp  \
# 948             0               0      2.043954  2022-12-21 13:19:23.255841
# 1069            1               5    183.085114  2022-12-21 21:57:07.659384
# 1524            1               5    198.636497  2022-12-27 16:28:55.551267
# 2712            0               0      7.184033  2023-01-06 17:16:15.210606
# 2713            0               0      7.184033  2023-01-06 17:16:15.210606
# 2715            0               0      7.184033  2023-01-06 17:16:15.210606
# 2718            0               0      7.184033  2023-01-06 17:16:15.210606
# 2722            0               0      7.184033  2023-01-06 17:16:15.210606
# 2727            0               0      7.184033  2023-01-06 17:16:15.210606
# 2733            0               0      7.184033  2023-01-06 17:16:15.210606
#
#            User            subdir_id
# 948   Rav Super  R014207816_3413-43A
# 1069        Rav  R014207816_3413-43A
# 1524        Rav  R014207816_3413-43A
# 2712        Rav  R014207816_3413-43A
# 2713        Rav  R014207816_3413-43A
# 2715        Rav  R014207816_3413-43A
# 2718        Rav  R014207816_3413-43A
# 2722        Rav  R014207816_3413-43A
# 2727        Rav  R014207816_3413-43A
# 2733        Rav  R014207816_3413-43A

# %% [markdown]
# Find any subdirectories that have not been processed:

# %%
df_inventory = pd.read_csv(logDir + 'image_inventory.csv')
print(len(df_inventory))
df_inventory.head()
# Out:
# 2638
#          Roll Subdirectory  images            subdir_id
# 0  R014207815     3488-15A     273  R014207815_3488-15A
# 1  R014207815     3489-15A     281  R014207815_3489-15A
# 2  R014207815     3490-15A     198  R014207815_3490-15A
# 3  R014207815      3491-8A     289   R014207815_3491-8A
# 4  R014207815      3492-8A     334   R014207815_3492-8A

# %%
subdir_ids_tot = df_inventory['subdir_id'].unique()
subdir_ids_proc = df_p1['subdir_id'].unique()
subdir_ids_rem = list(set(subdir_ids_tot) - set(subdir_ids_proc))
subdir_ids_rem
# Out:
# ['R014207949_2114-1A']

# %% [markdown]
# Only 1 subdirectory did not get processed! Process it, then continue.
