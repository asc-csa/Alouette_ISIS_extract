# %%
import pandas as pd
import keras_ocr
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\rnaidoo\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\rnaidoo\.keras-ocr\crnn_kurapan.h5

# %%
img_fn = 'L:/DATA/Alouette_I/BATCH_II_Run1/04_processed/R014207817/4163-03A/6.png'

# %%
img = mpimg.imread(img_fn)
plt.imshow(img)

# %%
img_ocr = keras_ocr.tools.read(img_fn)

# %%
prediction_groups = pipeline.recognize([img_ocr])
# Out:
# 1/1 [==============================] - 12s 12s/step
# 1/1 [==============================] - 2s 2s/step

# %%
df_ocr = pd.DataFrame()
predicted_image = prediction_groups[0]
for text, box in predicted_image:
    print(text)
    row = pd.DataFrame({
        'number': text,
        'x': box[1][0],
        'y': box[1][1]
    }, index=[0])
    df_ocr = pd.concat([df_ocr, row])
# Out:
# 66
# 339
# 1905
# 43
# 03
# 10

# %%
df_ocr = df_ocr.sort_values('x').reset_index(drop=True)
df_ocr
# Out:
#   number           x           y
# 0     10  303.750000  747.562500
# 1     03  401.625000  745.875000
# 2     66  505.895081  734.692322
# 3    339  635.336365  745.304626
# 4   1905  797.913635  743.631958
# 5     43  897.750000  744.187500

# %%
len(df_ocr)
# Out:
# 6

# %%
mean = df_ocr['y'].mean()
sd = df_ocr['y'].std()
print(mean)
print(sd)
# Out:
# 743.5422973632812
# 4.5487518310546875

# %%
n_std = 5
df_ocr = df_ocr[(df_ocr['y'] <= mean+(n_std*sd))]
df_ocr = df_ocr[(df_ocr['y'] >= mean-(n_std*sd))]

# %%
df_ocr
# Out:
#   number           x           y
# 0     10  303.750000  747.562500
# 1     03  401.625000  745.875000
# 2     66  505.895081  734.692322
# 3    339  635.336365  745.304626
# 4   1905  797.913635  743.631958
# 5     43  897.750000  744.187500
